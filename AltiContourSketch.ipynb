# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from osgeo import gdal
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
# import elevation

# %%
filename = "CookBooks/Sources/ShapeFiles/elevation9x9/elevation9x9.tif"
gdal_data = gdal.Open(filename)
gdal_band = gdal_data.GetRasterBand(1)
nodataval = gdal_band.GetNoDataValue()

# convert to a numpy array
data_array = gdal_data.ReadAsArray().astype(np.float)
data_array = np.flip(data_array)
data_array = np.fliplr(data_array)

# replace missing values if necessary
if np.any(data_array == nodataval):
    data_array[data_array == nodataval] = np.nan

# %%
/Users/maartenk/Documents/git/CookBooks/Sources/ShapeFiles/elevation9x9/elevation9x9.tif
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-438f76a06dc0> in <module>
# ----> 1 Users/maartenk/Documents/git/CookBooks/Sources/ShapeFiles/elevation9x9/elevation9x9.tif()
#
# NameError: name 'Users' is not defined

# %%
# !pwd
# Out:
# /Users/maartenk/Documents/git

# %%
#Plot out data with Matplotlib's 'contour'
fig = plt.figure(figsize = (12, 8))
ax = fig.add_subplot(111)
plt.contour(data_array, cmap = "viridis", 
            levels = list(range(0, 5000, 50)))
plt.title("Elevation Contours of Mt. Shasta")
cbar = plt.colorbar()
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
#Plot out data with Matplotlib's 'contour'
fig = plt.figure(figsize = (12, 8))
ax = fig.add_subplot(111)
plt.contour(data_array, cmap = "viridis", 
            levels = list(range(0, 5000, 100)))
plt.title("Elevation Contours of Mt. Shasta")
cbar = plt.colorbar()
plt.gca().set_aspect('equal', adjustable='box')
plt.show()
