# %% [markdown]
# # Approximate inference
#
# _Author: Christoph Rahmede_

# %% [markdown]
# One of the main drawbacks of Bayesian modeling is surely the huge amount of computational resources required. For this reason, other methods having been invented to estimate the posterior.
#
# A computationally less intensive method which works also with larger datasets is based on variational inference. The posterior distribution is approximated by a simpler type of distribution and the distance between them is minimized. A simpler approximation is for example obtained by assuming independence of all model parameters.
#
# This approach turns finding the posterior into an optimization problem. Pymc3 includes a variety of methods for this purpose, for example Automatic Differentiation Variational Inference (ADVI).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.5)

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ## Load the data

# %%
from sklearn.datasets import load_iris

# %%
data = load_iris()
X = data.data
y = data.target

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=1)

# %% [markdown]
# ## Sklearn logistic regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='lbfgs',multi_class='ovr')
lr.fit(X_train,y_train)
lr.score(X_train,y_train)
# Out:
# 0.925

# %% [markdown]
# ## Bayesian logistic regression

# %%
import pymc3 as pm
import theano.tensor as tt
import theano

# %%
with pm.Model() as model:

    beta = pm.Normal('beta', 0, sd=10, shape=(4, 3))
    intercept = pm.Normal('intercept',0, 2, shape=(3,))
    p = tt.nnet.softmax(intercept+pm.math.dot(X, beta))

    observed = pm.Categorical('likelihood', p=p, observed=y)

# %% [markdown]
# ### Run the model with MCMC

# %%
with model:
    trace = pm.sample(1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [intercept, beta]
# Sampling 2 chains: 100%|██████████| 3000/3000 [00:39<00:00, 75.87draws/s]

# %%
pm.summary(trace)
# Out:
#                   mean        sd  mc_error    hpd_2.5   hpd_97.5        n_eff  \
# beta__0_0    -1.735837  7.430346  0.209613 -16.422278  12.647688  1258.632497
# beta__0_1     1.826743  6.416637  0.204142  -9.592352  15.028984   905.383475
# beta__0_2     0.512866  6.431596  0.206427 -11.086353  13.465347   907.848337
# beta__1_0     5.868590  6.562586  0.183344  -6.496432  18.681070  1083.432734
# beta__1_1    -2.718420  5.793442  0.180825 -13.964133   8.859299   975.068306
# beta__1_2    -3.617580  5.806584  0.180485 -14.972055   7.683109   989.029450
# beta__2_0    -8.908362  8.084869  0.240797 -24.584985   7.161448  1224.192916
# beta__2_1     1.161631  6.456748  0.189737 -11.691416  13.359871  1116.797999
# beta__2_2     8.634843  6.569125  0.198731  -3.996489  20.928913  1061.693465
# beta__3_0    -8.440614  8.130802  0.206572 -24.366848   6.925508  1509.780504
# beta__3_1     0.825344  6.138361  0.168772 -11.671286  12.390723  1185.472982
# beta__3_2     7.268613  6.167497  0.163958  -4.376686  19.540918  1215.425593
# intercept__0 -0.611625  1.891364  0.042415  -4.218648   3.249033  1661.271763
# intercept__1  4.373219  1.468458  0.041408   1.642268   7.259338  1325.205068
# intercept__2 -3.892176  1.515703  0.035531  -7.049262  -1.235253  1764.429992
#
#                   Rhat
# beta__0_0     1.000084
# beta__0_1     0.999577
# beta__0_2     0.999537
# beta__1_0     1.000064
# beta__1_1     0.999919
# beta__1_2     0.999735
# beta__2_0     0.999618
# beta__2_1     0.999505
# beta__2_2     0.999528
# beta__3_0     0.999570
# beta__3_1     1.000072
# beta__3_2     0.999856
# intercept__0  0.999695
# intercept__1  0.999516
# intercept__2  0.999771

# %%
pm.traceplot(trace)
plt.show()

# %%
from scipy.stats import mode

# %%
trace_ppc = pm.sample_posterior_predictive(trace,1000,model=model)['likelihood']
trace_predictions = mode(trace_ppc,axis=0).mode.ravel()
np.mean(y==trace_predictions)
# Out:
# 100%|██████████| 1000/1000 [00:11<00:00, 87.16it/s]
# 0.9733333333333334

# %% [markdown]
# ### Run the model with ADVI

# %%
with model:
    approx = pm.fit(15000, method='advi')
# Out:
# Average Loss = 60.303: 100%|██████████| 15000/15000 [00:18<00:00, 810.12it/s]
# Finished [100%]: Average Loss = 60.294

# %% [markdown]
# We can check for convergence (of the so-called evidence lower bound).

# %%
plt.plot(approx.hist)
plt.show()

# %% [markdown]
# We can use the approximation to obtain sample representing the posterior in the same way as a trace:

# %%
trace_approx = pm.sample_approx(approx, draws=1000)

# %%
trace_approx
# Out:
# <MultiTrace: 1 chains, 1000 iterations, 2 variables>

# %%
pm.summary(trace_approx)
# Out:
#                   mean        sd  mc_error   hpd_2.5  hpd_97.5
# beta__0_0    -1.797121  1.086314  0.028907 -3.785846  0.445029
# beta__0_1     0.523046  0.395277  0.014243 -0.253466  1.274685
# beta__0_2     0.489303  0.424142  0.013381 -0.377691  1.265721
# beta__1_0     2.173535  0.941322  0.028392  0.238152  3.979269
# beta__1_1    -0.706427  0.388848  0.012045 -1.450719  0.036601
# beta__1_2    -0.672028  0.420384  0.013465 -1.413429  0.208675
# beta__2_0    -3.113749  1.256304  0.040318 -5.684070 -0.797210
# beta__2_1    -0.139009  0.468414  0.012540 -1.094828  0.751398
# beta__2_2     1.786024  0.468942  0.013630  0.890692  2.706635
# beta__3_0    -3.115370  1.272582  0.039687 -5.513451 -0.572251
# beta__3_1    -0.980518  0.453437  0.014695 -1.856607 -0.148209
# beta__3_2     2.457190  0.550883  0.017341  1.415581  3.483565
# intercept__0 -1.064592  0.837827  0.028119 -2.531167  0.648401
# intercept__1  1.573014  0.330607  0.010483  0.965962  2.239795
# intercept__2 -1.365554  0.341298  0.010579 -2.071896 -0.753482

# %%
pm.traceplot(trace_approx)
plt.show()

# %%
approx_ppc = pm.sample_posterior_predictive(trace_approx,1000,model=model)['likelihood']
approx_predictions = mode(approx_ppc,axis=0).mode.ravel()
np.mean(y==approx_predictions)
# Out:
# 100%|██████████| 1000/1000 [00:11<00:00, 84.77it/s]
# 0.9666666666666667

# %%
Xt = theano.shared(X_train)
yt = theano.shared(y_train)

# %%
# In memory Minibatches for better speed
minibatch_size = 100
xs_t_minibatch = pm.Minibatch(X_train, minibatch_size)

with model:
    approx = pm.fit(
        15000,
        obj_optimizer=pm.rmsprop(learning_rate=0.001),
        more_replacements={Xt: xs_t_minibatch},
    )
# Out:
# /anaconda3/lib/python3.7/site-packages/pymc3/data.py:244: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   self.shared = theano.shared(data[in_memory_slc])
#   0%|          | 0/15000 [00:00<?, ?it/s]/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Average Loss = 46.794: 100%|██████████| 15000/15000 [00:17<00:00, 871.38it/s]
# Finished [100%]: Average Loss = 46.794

# %%
plt.plot(approx.hist);

# %%
samples = pm.sample_approx(approx, draws=1000)

# %%
pm.sample_posterior_predictive(samples,10,model=model)['likelihood'].shape
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 79.60it/s]
# (10, 150)

# %%
pm.summary(samples)
# Out:
#                   mean        sd  mc_error    hpd_2.5  hpd_97.5
# beta__0_0    -2.517304  1.742269  0.046362  -5.706891  1.078735
# beta__0_1     0.974134  0.530965  0.019133  -0.068935  1.983793
# beta__0_2     0.434869  0.566420  0.017869  -0.722958  1.471738
# beta__1_0     3.581679  1.385051  0.041776   0.733975  6.238618
# beta__1_1    -0.721017  0.487712  0.015108  -1.654544  0.210924
# beta__1_2    -1.436531  0.526958  0.016879  -2.365888 -0.332559
# beta__2_0    -5.549404  2.309047  0.074104 -10.273574 -1.291677
# beta__2_1    -0.732845  0.624516  0.016719  -2.007198  0.454299
# beta__2_2     3.497100  0.592466  0.017220   2.365929  4.660209
# beta__3_0    -5.632802  2.350560  0.073306 -10.062248 -0.935457
# beta__3_1    -1.664521  0.644595  0.020890  -2.909948 -0.481329
# beta__3_2     4.326542  0.759016  0.023892   2.891395  5.740699
# intercept__0 -0.901410  1.284327  0.043104  -3.149560  1.724480
# intercept__1  3.119954  0.429887  0.013632   2.330606  3.986967
# intercept__2 -2.916339  0.426201  0.013211  -3.798393 -2.152004

# %%
pm.traceplot(samples)
plt.show()
