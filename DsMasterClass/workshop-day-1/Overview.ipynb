# %% [markdown]
# # Workshops
#
# ## 1. Data Wrangling and Visualization
#
# ### Dates
#
# - 04 February
# - 05 February
# - 07 February
#
# ### Topics
#
# - Plotting with matplotlib, pandas and seaborn
# - Grouping/Pivoting with pandas
# - Plots for regression/classification/clustering
#
# ![](./images/fig_learning.png)

# %% [markdown]
# ## 2. Statistics
#
# ### Dates
#
# - 11 February
# - 12 February
#
#
# ### Topics
#
# - Review of distributions
# - Confidence intervals
# - Central limit theorem
# - Bootstrapping
# - Hypothesis testing
# - Simpson’s paradox
#
#
#
# <img src="./images/fig_stats.png" style="width:400px;height:300px;">
#
#
# ## 3. Bayesian Modeling
#
# ### Dates
#
# - 25 February
# - 26 February
# - 28 February
#
# ### Topics
#
# - Basics of Bayesian approach
# - Difference to frequentist approach
# - Priors and posteriors
# - Sampling techniques and implementation of the main models with pymc3
#
# ![](./images/fig_pymc3.png)
#
# ## 4. Neural Networks
#
#
# ### Dates
#
# - 05 March
# - 07 March
#
#
# ### Topics
#
# - Overview of neural networks
# - Fitting and tuning
# - Implementation in sklearn and tensorflow
#
# ![](./images/fig_nnet.png)
