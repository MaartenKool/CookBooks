# %% [markdown]
# # Matplotlib plotting

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-and-clean-the-data" data-toc-modified-id="Load-and-clean-the-data-1">Load and clean the data</a></span></li><li><span><a href="#Variable-types" data-toc-modified-id="Variable-types-2">Variable types</a></span><ul class="toc-item"><li><span><a href="#Histogram" data-toc-modified-id="Histogram-2.1">Histogram</a></span><ul class="toc-item"><li><span><a href="#Ex:-Look-at-other-histograms.-What-do-you-observe?" data-toc-modified-id="Ex:-Look-at-other-histograms.-What-do-you-observe?-2.1.1">Ex: Look at other histograms. What do you observe?</a></span></li></ul></li><li><span><a href="#Bar-plot" data-toc-modified-id="Bar-plot-2.2">Bar plot</a></span></li><li><span><a href="#Getting-the-brands" data-toc-modified-id="Getting-the-brands-2.3">Getting the brands</a></span><ul class="toc-item"><li><span><a href="#Ex:-Looking-at-the-different-brands,-find-out-what-the-origin-stands-for." data-toc-modified-id="Ex:-Looking-at-the-different-brands,-find-out-what-the-origin-stands-for.-2.3.1">Ex: Looking at the different brands, find out what the origin stands for.</a></span></li></ul></li><li><span><a href="#Pie-chart" data-toc-modified-id="Pie-chart-2.4">Pie chart</a></span></li><li><span><a href="#Scatter-plot" data-toc-modified-id="Scatter-plot-2.5">Scatter plot</a></span></li><li><span><a href="#Line-plot" data-toc-modified-id="Line-plot-2.6">Line plot</a></span></li><li><span><a href="#Boxplot" data-toc-modified-id="Boxplot-2.7">Boxplot</a></span></li><li><span><a href="#Figure-objects" data-toc-modified-id="Figure-objects-2.8">Figure objects</a></span></li></ul></li><li><span><a href="#Combining-multiple-figures" data-toc-modified-id="Combining-multiple-figures-3">Combining multiple figures</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Ex:-Try-to-combine-at-least-four-different-plots-into-a-single-figure-and-tune-the-plots-with-everything-seen-above." data-toc-modified-id="Ex:-Try-to-combine-at-least-four-different-plots-into-a-single-figure-and-tune-the-plots-with-everything-seen-above.-3.0.1">Ex: Try to combine at least four different plots into a single figure and tune the plots with everything seen above.</a></span></li></ul></li></ul></li><li><span><a href="#Plotting-styles" data-toc-modified-id="Plotting-styles-4">Plotting styles</a></span></li><li><span><a href="#Saving-a-figure" data-toc-modified-id="Saving-a-figure-5">Saving a figure</a></span></li><li><span><a href="#Resources" data-toc-modified-id="Resources-6">Resources</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.5)

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## Load and clean the data
#
# We will work with a dataset about cars. You can look up details about the dataset in the datafolder or [here](https://archive.ics.uci.edu/ml/datasets/Auto+MPG). We will first have to clean the data.

# %%
df = pd.read_csv('../../../dataset-collection/auto-mpg/auto-mpg.csv',
                 sep='\s+', header=None)

# %%
# rename the columns
df.columns = ['mpg', 'cylinders', 'displacement', 'horsepower',
              'weight', 'acceleration', 'year', 'origin', 'name']

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0    70
# 1  15.0          8         350.0      165.0  3693.0          11.5    70
# 2  18.0          8         318.0      150.0  3436.0          11.0    70
# 3  16.0          8         304.0      150.0  3433.0          12.0    70
# 4  17.0          8         302.0      140.0  3449.0          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# data types and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      398 non-null object
# weight          398 non-null float64
# acceleration    398 non-null float64
# year            398 non-null int64
# origin          398 non-null int64
# name            398 non-null object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
# why is horsepower type object
df.horsepower.unique()
# Out:
# array(['130.0', '165.0', '150.0', '140.0', '198.0', '220.0', '215.0',
#        '225.0', '190.0', '170.0', '160.0', '95.00', '97.00', '85.00',
#        '88.00', '46.00', '87.00', '90.00', '113.0', '200.0', '210.0',
#        '193.0', '?', '100.0', '105.0', '175.0', '153.0', '180.0', '110.0',
#        '72.00', '86.00', '70.00', '76.00', '65.00', '69.00', '60.00',
#        '80.00', '54.00', '208.0', '155.0', '112.0', '92.00', '145.0',
#        '137.0', '158.0', '167.0', '94.00', '107.0', '230.0', '49.00',
#        '75.00', '91.00', '122.0', '67.00', '83.00', '78.00', '52.00',
#        '61.00', '93.00', '148.0', '129.0', '96.00', '71.00', '98.00',
#        '115.0', '53.00', '81.00', '79.00', '120.0', '152.0', '102.0',
#        '108.0', '68.00', '58.00', '149.0', '89.00', '63.00', '48.00',
#        '66.00', '139.0', '103.0', '125.0', '133.0', '138.0', '135.0',
#        '142.0', '77.00', '62.00', '132.0', '84.00', '64.00', '74.00',
#        '116.0', '82.00'], dtype=object)

# %%
# missing horsepower rows
df[df.horsepower == '?']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 32   25.0          4          98.0          ?  2046.0          19.0    71
# 126  21.0          6         200.0          ?  2875.0          17.0    74
# 330  40.9          4          85.0          ?  1835.0          17.3    80
# 336  23.6          4         140.0          ?  2905.0          14.3    80
# 354  34.5          4         100.0          ?  2320.0          15.8    81
# 374  23.0          4         151.0          ?  3035.0          20.5    82
#
#      origin                  name
# 32        1            ford pinto
# 126       1         ford maverick
# 330       2  renault lecar deluxe
# 336       1    ford mustang cobra
# 354       2           renault 18i
# 374       1        amc concord dl

# %%
# drop missing values
df.drop(df[df.horsepower == '?'].index, inplace=True)

# %%
# convert to float
df['horsepower'] = df.horsepower.astype(float)

# %%
# check info again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             392 non-null float64
# cylinders       392 non-null int64
# displacement    392 non-null float64
# horsepower      392 non-null float64
# weight          392 non-null float64
# acceleration    392 non-null float64
# year            392 non-null int64
# origin          392 non-null int64
# name            392 non-null object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 30.6+ KB

# %%
df.describe(include='all')
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   392.000000  392.000000    392.000000  392.000000   392.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.445918    5.471939    194.411990  104.469388  2977.584184
# std       7.805007    1.705783    104.644004   38.491160   849.402560
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%      22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%      29.000000    8.000000    275.750000  126.000000  3614.750000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration        year      origin            name
# count     392.000000  392.000000  392.000000             392
# ...

# %% [markdown]
# ## Variable types
#
# In any kind of dataset we will meet variables of different type.
#
# - Categorical variables
#     - Nominal: categories without order, e.g. male/female
#     - Ordinal: categories with order, e.g. ranking from a race
#
# - Metric variables
#     - Discrete, e.g. counts
#     - Continuous, e.g. temperature or time

# %% [markdown]
# ### Histogram

# %% [markdown]
# Histograms are used to depict the distribution of continuous variables.

# %%
plt.hist(df.mpg)
plt.show()

# %% [markdown]
# Note the last command which has been added to suppress junk output:
#
# ```python
# plt.show()
# ```
#
# Alternatively you can add a semicolon.
#
# Let's look at another variable.

# %%
plt.hist(df.horsepower, bins=20, density=True)
plt.xlabel('horsepower')
plt.show()

# %% [markdown]
# #### Ex: Look at other histograms. What do you observe?

# %%
for col in df.columns:
    if df[col].dtype!='O':
        plt.hist(df[col],bins=20, density=True)
        plt.xlabel(col)
        plt.show()

# %% [markdown]
# ### Bar plot
#
# Bar plots serve for comparing metric variables across different categories.

# %%
counts = df.origin.value_counts()
plt.bar(counts.index, counts.values, color=['r', 'b', 'g'])
plt.xlabel('origin')
plt.ylabel('counts')
plt.show()

# %% [markdown]
# ### Getting the brands
#
# We have one entry for each type of car, but many of them belong to the same brand. Let's extract the brand name.

# %%
df.name.map(lambda x: x.split(' ')[0]).unique()
# Out:
# array(['chevrolet', 'buick', 'plymouth', 'amc', 'ford', 'pontiac',
#        'dodge', 'toyota', 'datsun', 'volkswagen', 'peugeot', 'audi',
#        'saab', 'bmw', 'chevy', 'hi', 'mercury', 'opel', 'fiat',
#        'oldsmobile', 'chrysler', 'mazda', 'volvo', 'renault', 'toyouta',
#        'maxda', 'honda', 'subaru', 'chevroelt', 'capri', 'vw',
#        'mercedes-benz', 'cadillac', 'mercedes', 'vokswagen', 'triumph',
#        'nissan'], dtype=object)

# %% [markdown]
# Since there are some spelling mistakes, let's clean the names up.

# %%
df['brand'] = df.name.map(lambda x: x.split(' ')[0]
                          ).replace(
    {'toyouta': 'toyota',
     'maxda': 'mazda',
     'chevroelt': 'chevrolet',
     'vw': 'volkswagen',
     'vokswagen': 'volkswagen',
     'mercedes-benz': 'mercedes'})

# %%
counts = df.brand.value_counts()
plt.figure(figsize=(12, 12))
plt.barh(counts.index, counts.values)
plt.xlabel('counts')
plt.ylabel('brands')
plt.show()

# %% [markdown]
# #### Ex: Looking at the different brands, find out what the origin stands for.

# %%
for i in np.sort(df.origin.unique()):
    print(i)
    print(df.brand[df.origin == i].unique())
    print()
# Out:
# 1
# ['chevrolet' 'buick' 'plymouth' 'amc' 'ford' 'pontiac' 'dodge' 'chevy'
#  'hi' 'mercury' 'oldsmobile' 'chrysler' 'capri' 'cadillac']
#
# 2
# ['volkswagen' 'peugeot' 'audi' 'saab' 'bmw' 'opel' 'fiat' 'volvo'
#  'renault' 'mercedes' 'triumph']
#
# 3
# ['toyota' 'datsun' 'mazda' 'honda' 'subaru' 'nissan']

# %% [markdown]
# ### Pie chart
#
# Pie charts are popular, but really only useful if the different parts sum up to 1, and if they are depicted together with the fractions or percentages. With the pure eye it is challenging to compare the exact proportions between different slices. Bar plots are always preferred!

# %%
df['continent'] = df.origin.map(
    lambda x: 'America' if x == 1 else 'Europe' if x == 2 else 'Asia')

# %%
counts = df.continent.value_counts(normalize=True)
plt.pie(counts.values, labels=counts.index, labeldistance=1.1, autopct='%1.1f%%',
        textprops={'fontsize': 20}, explode=[0, 0, 0.1], shadow=True, startangle=90)
plt.show()

# %% [markdown]
# ### Scatter plot
#
# A scatter plot informs us about the relation between two variables.

# %%
plt.scatter(df.horsepower, df.mpg)
plt.xlabel('horsepower')
plt.ylabel('mpg')
plt.show()

# %%
plt.scatter(df.horsepower, df.mpg)
plt.xlabel('horsepower')
plt.ylabel('mpg')
plt.xticks()
plt.show()

# %%
plt.scatter(df.year, df.mpg)
plt.xlabel('year')
plt.ylabel('mpg')
plt.show()

# %% [markdown]
# ### Line plot
#
# Also a line plot can serve for depicting a relation between two variables. Keep in mind that to get something useful the x-values should be ordered.

# %%
mpgs = []
years = np.sort(df.year.unique())
for year in years:
    mpgs.append(df[df.year == year].mpg.mean())

# %%
plt.scatter(years, mpgs)
plt.plot(years, mpgs, lw=2)
plt.xticks(years)
plt.xlabel('year')
plt.ylabel('mean mpg')
plt.show()

# %% [markdown]
# ### Boxplot
#
# A box plot is another way for depicting the distribution of a variable. It consists of the following parts (to be read for vertical box plots):
#
# - box: height defined by the interquartile range of the variable (25th and 75th percentile)
# - median: the line in the center marking the 50th percentile.
# - the whiskers: the vertical lines departing from the box, extending up to the maximal/minimal value or at most up to 1.5 times the interquartile range from the box boundary (can be adjusted by the `whis` argument, 1.5 is the default value). The actual boundary is at the last observation within the whisker distance.
# - caps: horizontal lines at the end of the whiskers
#
# Any points outside the range of the whiskers will be represented by individual markers. That serves to discover outliers easily.
#
# Let's look at two examples.

# %%
plt.boxplot(df.weight, sym='d', showfliers=True, whis=1.5)
plt.xticks([1], ['weight'])
plt.show()

# %%
plt.boxplot(df.horsepower, sym='d', showfliers=True, whis=1.5)
plt.xticks([1], ['horsepower'])
plt.show()

# %% [markdown]
# Let's illustrate what the individual parts stand for.

# %%
x_min = 0.9,
x_max = 1.1
median = df.horsepower.median()
h_max = df.horsepower.max()
h_min = df.horsepower.min()
percentile_25 = df.horsepower.describe()['25%']
percentile_75 = df.horsepower.describe()['75%']

upper_whis = percentile_75+1.5*(percentile_75-percentile_25)
lower_whis = percentile_25-1.5*(percentile_75-percentile_25)
upper_cap = df.horsepower[df.horsepower < upper_whis].max()

# that is the upper cap, every point beyond will be represented by a marker
upper_cap
# Out:
# 200.0

# %%
plt.boxplot(df.horsepower, sym='d', whis=1.5)
plt.xticks([1], ['horsepower'])
plt.hlines(median, x_min, x_max, color='b')
plt.hlines(percentile_25, x_min, x_max, color='b')
plt.hlines(percentile_75, x_min, x_max, color='b')
plt.hlines(h_min, x_min, x_max, color='b')
plt.hlines(h_max, x_min, x_max, color='b')
plt.hlines(upper_cap, x_min, x_max, color='b')
plt.hlines(upper_whis, x_min, x_max, color='b')

fontsize = 12
arrowprops = dict(arrowstyle='->', color='black', linewidth=1.5)

plt.annotate('median',
             (1.1, median),
             xytext=(1.2, median),
             fontsize=fontsize,
             arrowprops=arrowprops)

plt.annotate('25th percentile',
             (1.1, percentile_25),
             xytext=(1.2, percentile_25),
             fontsize=fontsize,
             arrowprops=arrowprops)

plt.annotate('75th percentile',
             (1.1, percentile_75),
             xytext=(1.2, percentile_75),
             fontsize=fontsize,
             arrowprops=arrowprops)

plt.annotate(r'$75{\rm th}\,{\rm percentile}\,$'+'\n'+r'$+ 1.5\cdot {\rm IQR}$',
             (1.1, upper_whis),
             xytext=(1.2, upper_whis),
             fontsize=fontsize,
             arrowprops=arrowprops
             )

plt.annotate('upper cap',
             (0.9, upper_cap),
             xytext=(0.7, upper_cap),
             fontsize=12,
             arrowprops=arrowprops
             )

plt.annotate('maximum',
             (1.1, h_max),
             xytext=(1.2, h_max),
             fontsize=12,
             arrowprops=arrowprops
             )

plt.annotate('minimum',
             (1.1, h_min),
             xytext=(1.2, h_min),
             fontsize=12,
             arrowprops=arrowprops
             )

plt.show()

# %% [markdown]
# We can also plot several variables with boxplots together.

# %%
plt.boxplot([df.horsepower, df.mpg, df.weight], sym='d', showfliers=True)
plt.xticks(range(1, 4), ['horsepower', 'mpg', 'weight'])
plt.show()

# %% [markdown]
# Apparently we have a problem with differing scales. As a remedy, the most common approach is to standardize the variables by subtracting the mean and dividing by the standard deviation. This produces unit-less numbers which express how many standard deviations any observation is above or below the mean.

# %%
def standardizer(x):
    return (x-x.mean())/x.std()

# %%
plt.boxplot([standardizer(df.horsepower),
             standardizer(df.mpg),
             standardizer(df.weight)],
            sym='d',
            showfliers=True)
plt.xticks(range(1, 4), ['horsepower', 'mpg', 'weight'])
plt.show()

# %% [markdown]
# ### Figure objects
#
# So far we have been working in an interactive way. That is nice for experimenting and small amounts of data since we can easily run a cell again after we changed any aspect of the figure. The more sophisticated way is to work with figure objects which can be saved and whose properties we can modify without having to recreate the whole figure again.
#
# Each matplotlib figure consists of two objects, conventionally referred to as `ax` and `fig`.
# The `ax` object contains all the metadata about the figure, `fig` is the figure itself.

# %%
fig, ax = plt.subplots()
ax.scatter(years, mpgs)
ax.plot(years, mpgs, lw=2)
ax.set_xticks(years)
ax.set_xlabel('year')
ax.set_ylabel('mean mpg')
plt.show()

# %%
# the ax object
ax

# %% [markdown]
# We can now modify attributes of the ax-object and display the updated figure.

# %%
ax.set_title('Mean mpg per year')
fig

# %% [markdown]
# ## Combining multiple figures
#
# We can easily create combinations of different figures by specifying how many figures we intend to construct and then referring to each entry with numpy matrix notation. We indicate how many figures we want with the keywords `nrows` and `ncols` in `plt.subplots`. Then we can set up for example the upper left figure with
#
# ```python
# fig, ax = plt.subplots(nrows=2, ncols=2,figsize=(6,6))
# ax[0, 0].scatter(....)
# ```

# %% [markdown]
# #### Ex: Try to combine at least four different plots into a single figure and tune the plots with everything seen above.

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
ax[0, 0].scatter(years, mpgs, color='darkorange', s=60, label='observed')
ax[0, 0].plot(years, mpgs, c='b', lw=3)
ax[0, 0].set_xticks(years)
ax[0, 0].set_xlabel('year')
ax[0, 0].set_ylabel('mean mpg')
ax[0, 0].legend()


ax[0, 1].boxplot([
    standardizer(df.horsepower),
    standardizer(df.mpg),
    standardizer(df.weight)],
    sym='d',
    showfliers=True,
    patch_artist=True,
    showmeans=True,
    meanline=True,
        boxprops={'linestyle': '-.', 'linewidth': 3, 'facecolor': 'b'},
        medianprops={'linewidth': 4, 'linestyle': '-'},
        meanprops={'linewidth': 2, 'linestyle': '--', 'color': 'k'},
        flierprops={'marker': 'v', 'markersize': 10,
                    'markerfacecolor': 'g', 'markeredgecolor': 'g'},
        whiskerprops={'linestyle': '-', 'linewidth': 4},
        capprops={'linestyle': '-', 'linewidth': 4}
)
ax[0, 1].set_xticklabels(['horsepower', 'mpg', 'weight'])

for continent, color, symbol in zip(list(df.continent.unique()), ['b', 'darkorange', 'g'], ['o', 'd', 'v']):
    ax[1, 0].scatter(df.horsepower[df.continent == continent], df.mpg[df.continent == continent],
                     c=color, marker=symbol, label=continent)

ax[1, 0].set_xlabel('horsepower')
ax[1, 0].set_ylabel('mpg')
ax[1, 0].legend(facecolor='grey', framealpha=0.25)

ax[1, 1].pie(counts.values, labels=counts.index, labeldistance=1.1, radius=0.8, autopct='%1.1f%%',
             textprops={'fontsize': 20}, explode=[0, 0, 0.1], shadow=True, startangle=90)
fig.suptitle('Miles per gallon', fontsize=30)
plt.show()

# %% [markdown]
# ## Plotting styles

# %% [markdown]
# Matplotlib works with a lot of default parameters. They are stored in a dictionary which you can have a look at with
#
# ```python
# plt.rcParams
# ```
#
# You can change any of those, for example the standard linewidth. Be careful!

# %%
standardlinewidth = plt.rcParams['lines.linewidth']
standardlinewidth
# Out:
# 1.5

# %%
plt.rcParams['lines.linewidth'] = 8

# %%
plt.scatter(years, mpgs)
plt.plot(years, mpgs)
plt.xticks(years)
plt.xlabel('year')
plt.ylabel('mean mpg')
plt.show()

# %%
plt.rcParams['lines.linewidth'] = standardlinewidth

# %%
plt.scatter(years, mpgs)
plt.plot(years, mpgs)
plt.xticks(years)
plt.xlabel('year')
plt.ylabel('mean mpg')
plt.show()

# %% [markdown]
# Matplotlib has many different style choices available:

# %%
print(plt.style.available)
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %% [markdown]
# You can pick any of these styles with something like
#
# ```python
# plt.style.use('seaborn-dark')
# ```
#
# That will make this style permanent (for your session).
# If you just want to change the style temporarily, try the following:

# %%
with plt.style.context(('fivethirtyeight')):
    fig_1, ax_1 = plt.subplots()
    ax_1.scatter(years, mpgs)
    ax_1.plot(years, mpgs, lw=2)
    ax_1.set_xticks(years)
    ax_1.set_xlabel('year')
    ax_1.set_ylabel('mean mpg')

# %%
with plt.xkcd(randomness=10):
    fig_1, ax_1 = plt.subplots(ncols=2,figsize=(12,4))
    ax_1[0].scatter(years, mpgs, color='r', s=80)
    ax_1[0].plot(years, mpgs, lw=2)
    ax_1[0].set_xticks(years)
    ax_1[0].set_xlabel('year')
    ax_1[0].set_ylabel('mean mpg')
    ax_1[1].boxplot(df.weight, sym='d', showfliers=True, whis=1.5)
    ax_1[1].set_xticks([1], ['weight']);

# %% [markdown]
# The global style is still the same:

# %%
plt.plot(years, mpgs, alpha=0.8)
plt.scatter(years, mpgs,color='r',s=50)
plt.xticks(years)
plt.xlabel('year')
plt.ylabel('mean mpg')
plt.show()

# %% [markdown]
# ## Saving a figure
#
# Saving a figure is simple, just specify the filename and the format.

# %%
fig.savefig('figure.pdf', format='pdf')

# %% [markdown]
# ## Resources
#
# - The indispensable matplotlib [gallery](https://matplotlib.org/gallery/index.html#)
