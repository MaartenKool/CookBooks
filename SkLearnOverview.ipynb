# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd

# %%
#cell to find sklearn estimators with handy (i.e. less common) methods
from sklearn.utils.testing import all_estimators

estimators = all_estimators(include_meta_estimators=True, include_other=True)
nestimators = len(estimators)
#create (empty) lists
est_list = [estimator[0] for estimator in estimators]
predict_proba_list = [""] * nestimators
feature_importances__list = [""] * nestimators
predict_log_proba_list = [""] * nestimators
decision_function_list = [""] * nestimators

# iterate through lists checking for specific classes
i=0
for name, class_ in estimators:
    if hasattr(class_, 'predict_proba'):
            predict_proba_list[i] = True
    else:
        predict_proba_list[i] = False
        
    if hasattr(class_, 'feature_importances_'):
            feature_importances__list[i] = True
    else:
        feature_importances__list[i] = False
        
    if hasattr(class_, 'predict_log_proba'):
            predict_log_proba_list[i] = True
    else:
        predict_log_proba_list[i] = False
        
    if hasattr(class_, 'decision_function'):
            decision_function_list[i] = True
    else:
        decision_function_list[i] = False
        
    i += 1
#combine lists       
feat = [('Predict_proba', predict_proba_list),
        ('Feature Importance', feature_importances__list),
        ('predict_log_proba', predict_log_proba_list),
        ('decision_function', decision_function_list)
        ]
#create df
df = pd.DataFrame.from_items(feat)
df.index=est_list
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %%
#df.shape

# %%
#print(len(est_list))
#print(nestimators)

# %%
#cell to find estimators with specific handy 'parameters'
#needs to be seperate because the instantiation 'class()' does not work with  all_estimators(include_meta/other = True)
from sklearn.utils.testing import all_estimators


estimators = all_estimators()#(include_meta_estimators=True, include_other=True) does not work
nestimators = len(estimators)
est_list = [estimator[0] for estimator in estimators]

class_weigth_list = [""] * nestimators

i=0

for name, class_ in estimators:
        
    if hasattr(class_(), 'class_weight'): # Note the parenthesis: class_() 
        class_weigth_list[i] = True
    else:
        class_weigth_list[i] = False
    i += 1
      
feat = [
        ('class_weigth', class_weigth_list)
        
       ]
    
df_ = pd.DataFrame.from_items(feat)
df_.index=est_list
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class DPGMM is deprecated; The `DPGMM` class is not working correctly and it's better to use `sklearn.mixture.BayesianGaussianMixture` class with parameter `weight_concentration_prior_type='dirichlet_process'` instead. DPGMM is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class GMM is deprecated; The class GMM is deprecated in 0.18 and will be  removed in 0.20. Use class GaussianMixture instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class GaussianProcess is deprecated; GaussianProcess was deprecated in version 0.18 and will be removed in 0.20. Use the GaussianProcessRegressor instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/neighbors/approximate.py:220: DeprecationWarning: LSHForest has poor performance and has been deprecated in 0.19. It will be removed in version 0.21.
#   DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class RandomizedLasso is deprecated; The class RandomizedLasso is deprecated in 0.19 and will be removed in 0.21.
#   warnings.warn(msg, category=DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class RandomizedLogisticRegression is deprecated; The class RandomizedLogisticRegression is deprecated in 0.19 and will be removed in 0.21.
#   warnings.warn(msg, category=DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class RandomizedPCA is deprecated; RandomizedPCA was deprecated in 0.18 and will be removed in 0.20. Use PCA(svd_solver='randomized') instead. The new implementation DOES NOT store whiten ``components_``. Apply transform to get them.
#   warnings.warn(msg, category=DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class VBGMM is deprecated; The `VBGMM` class is not working correctly and it's better to use `sklearn.mixture.BayesianGaussianMixture` class with parameter `weight_concentration_prior_type='dirichlet_distribution'` instead. VBGMM is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
df_.shape
# Out:
# (153, 1)

# %%
#create list of estimator types
classifiers_=[('classifier',*all_estimators(type_filter= 'classifier')[i]) for i in range(0,len(all_estimators(type_filter= 'classifier')))]
regressors_=[('regressor',*all_estimators(type_filter= 'regressor')[i]) for i in range(0,len(all_estimators(type_filter= 'regressor')))]
clusters_=[('cluster',*all_estimators(type_filter= 'cluster')[i]) for i in range(0,len(all_estimators(type_filter= 'cluster')))]
transformers_=[('transformer',*all_estimators(type_filter= 'transformer')[i]) for i in range(0,len(all_estimators(type_filter= 'transformer')))]
unknowns_=[('unknown',*all_estimators(type_filter= None)[i]) for i in range(0,len(all_estimators(type_filter= None)))]

# %%
#create a list of meta estimators
estimators__ = all_estimators(include_meta_estimators=True)
estimators___ = all_estimators(include_meta_estimators=False)
meta_estimators = list(set(estimators__)-set(estimators___))
meta_estimators_ = [('meta estimators', *meta_estimators[i]) for i in range(0, len(meta_estimators))]
#meta_estimators_

# %%
#cteae a list of meta estimators
others__ = all_estimators(include_other=True)
others___ = all_estimators(include_other=False)
others = list(set(others__)-set(others___))
others_ = [('others', *others[i]) for i in range(0, len(others))]
others_
# Out:
# [('others', 'GridSearchCV', sklearn.grid_search.GridSearchCV),
#  ('others',
#   'RandomizedSearchCV',
#   sklearn.model_selection._search.RandomizedSearchCV),
#  ('others', 'Pipeline', sklearn.pipeline.Pipeline),
#  ('others', 'RandomizedSearchCV', sklearn.grid_search.RandomizedSearchCV),
#  ('others', 'GridSearchCV', sklearn.model_selection._search.GridSearchCV),
#  ('others',
#   'SelectFromModel',
#   sklearn.feature_selection.from_model.SelectFromModel),
#  ('others', 'FeatureUnion', sklearn.pipeline.FeatureUnion)]

# %%
#combine
xx = clusters_+classifiers_+regressors_+transformers_+others_+meta_estimators_

# %%
len(xx)
# Out:
# 147

# %%
#create lists for name and type
type_list = [estimator[0] for estimator in xx]
len(type_list)

name_list = [estimator[1] for estimator in xx]
len(name_list)
# Out:
# 147

# %%
#into a df
df__ = pd.DataFrame()
df__['name'] = name_list
df__['type'] = type_list

df__.set_index('name', inplace=True)

# %%
#pull type and methods df together
df___ = pd.merge(df, df__ , left_index=True, right_index=True)

# %%
from IPython.display import HTML, display

#df___.style.set_properties(**{'text-align': 'left'})
styles = [
    dict(selector="th", props=[("font-size", "100%"),
                               ("text-align", "left"),
                              ("transform", "translate(0%,-30%) rotate(-5deg)")
                              ]),
    dict(selector=".row_heading, .blank", props= [('display', 'none;')])
]

html = df.style.set_table_styles(styles).render()
display(HTML(html))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-b8ba135ef3cb> in <module>()
#      10 ]
#      11
# ---> 12 html = df.style.set_table_styles(styles).render()
#      13 display(HTML(html))
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in style(self)
#     682         """
#     683         from pandas.io.formats.style import Styler
# --> 684         return Styler(self)
#     685
#     686     def iteritems(self):
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/formats/style.py in __init__(self, data, precision, table_styles, uuid, caption, table_attributes)
#     128             data = data.to_frame()
#     129         if not data.index.is_unique or not data.columns.is_unique:
# --> 130             raise ValueError("style is not supported for non-unique indicies.")
#     131
#     132         self.data = data
#
# ValueError: style is not supported for non-unique indicies.

# %%
df.shape
# Out:
# (168, 4)

# %%
df_.shape
# Out:
# (153, 1)

# %%
df__.shape
# Out:
# (147, 1)

# %%
# df.drop_duplicates(inplace=True) # Deprecation is causing multiple entries
# df.shape

# %%
df___.shape
# Out:
# (151, 5)

# %%
#merge df's with names, methos and parametrs
df____ = pd.merge(df___, df_ ,how='outer',left_index=True, right_index=True)
#df____.drop(['type_x'],axis=1,inplace=True)

# %%
df____.shape
# Out:
# (180, 6)

# %%
df____
# Out:
#                                         Predict_proba Feature Importance  \
# ARDRegression                                   False              False
# AdaBoostClassifier                               True               True
# AdaBoostRegressor                               False               True
# AdditiveChi2Sampler                             False              False
# AffinityPropagation                             False              False
# AgglomerativeClustering                         False              False
# BaggingClassifier                                True              False
# BaggingRegressor                                False              False
# BayesianGaussianMixture                           NaN                NaN
# BayesianRidge                                   False              False
# BernoulliNB                                      True              False
# BernoulliRBM                                    False              False
# Binarizer                                       False              False
# Birch                                           False              False
# Birch                                           False              False
# CCA                                             False              False
# CCA                                             False              False
# CalibratedClassifierCV                           True              False
# ClassifierChain                                  True              False
# DBSCAN                                          False              False
# DPGMM                                             NaN                NaN
# DecisionTreeClassifier                           True               True
# DecisionTreeRegressor                           False               True
# DictionaryLearning                              False              False
# ElasticNet                                      False              False
# ElasticNetCV                                    False              False
# EmpiricalCovariance                               NaN                NaN
# ExtraTreeClassifier                              True               True
# ExtraTreeRegressor                              False               True
# ExtraTreesClassifier                             True               True
# ...                                               ...                ...
# RobustScaler                                    False              False
# SGDClassifier                                    True              False
# SGDRegressor                                    False              False
# SVC                                              True              False
# SVR                                             False              False
# SelectFdr                                       False              False
# SelectFpr                                       False              False
# SelectFromModel                                 False              False
# SelectFwe                                       False              False
# SelectKBest                                     False              False
# SelectPercentile                                False              False
# ShrunkCovariance                                  NaN                NaN
# SkewedChi2Sampler                               False              False
# SparsePCA                                       False              False
# SparseRandomProjection                          False              False
# SpectralBiclustering                              NaN                NaN
# SpectralClustering                              False              False
# SpectralCoclustering                              NaN                NaN
# SpectralEmbedding                                 NaN                NaN
# StandardScaler                                  False              False
# TSNE                                              NaN                NaN
# TheilSenRegressor                               False              False
# VBGMM                                             NaN                NaN
# VarianceThreshold                               False              False
# _BaseRidgeCV                                      NaN                NaN
# _BinaryGaussianProcessClassifierLaplace           NaN                NaN
# _ConstantPredictor                                NaN                NaN
# _DPGMMBase                                        NaN                NaN
# _GMMBase                                          NaN                NaN
# _RidgeGCV                                         NaN                NaN
#
#                                         predict_log_proba decision_function  \
# ARDRegression                                       False             False
# AdaBoostClassifier                                   True              True
# AdaBoostRegressor                                   False             False
# AdditiveChi2Sampler                                 False             False
# AffinityPropagation                                 False             False
# AgglomerativeClustering                             False             False
# BaggingClassifier                                    True              True
# BaggingRegressor                                    False             False
# BayesianGaussianMixture                               NaN               NaN
# BayesianRidge                                       False             False
# BernoulliNB                                          True             False
# BernoulliRBM                                        False             False
# Binarizer                                           False             False
# Birch                                               False             False
# Birch                                               False             False
# CCA                                                 False             False
# CCA                                                 False             False
# CalibratedClassifierCV                              False             False
# ClassifierChain                                     False              True
# DBSCAN                                              False             False
# DPGMM                                                 NaN               NaN
# DecisionTreeClassifier                               True             False
# DecisionTreeRegressor                               False             False
# DictionaryLearning                                  False             False
# ElasticNet                                          False             False
# ElasticNetCV                                        False             False
# EmpiricalCovariance                                   NaN               NaN
# ExtraTreeClassifier                                  True             False
# ExtraTreeRegressor                                  False             False
# ExtraTreesClassifier                                 True             False
# ...                                                   ...               ...
# RobustScaler                                        False             False
# SGDClassifier                                        True              True
# SGDRegressor                                        False             False
# SVC                                                  True              True
# SVR                                                 False             False
# SelectFdr                                           False             False
# SelectFpr                                           False             False
# SelectFromModel                                     False             False
# SelectFwe                                           False             False
# SelectKBest                                         False             False
# SelectPercentile                                    False             False
# ShrunkCovariance                                      NaN               NaN
# SkewedChi2Sampler                                   False             False
# SparsePCA                                           False             False
# SparseRandomProjection                              False             False
# SpectralBiclustering                                  NaN               NaN
# SpectralClustering                                  False             False
# SpectralCoclustering                                  NaN               NaN
# SpectralEmbedding                                     NaN               NaN
# StandardScaler                                      False             False
# TSNE                                                  NaN               NaN
# TheilSenRegressor                                   False             False
# VBGMM                                                 NaN               NaN
# VarianceThreshold                                   False             False
# _BaseRidgeCV                                          NaN               NaN
# _BinaryGaussianProcessClassifierLaplace               NaN               NaN
# _ConstantPredictor                                    NaN               NaN
# _DPGMMBase                                            NaN               NaN
# _GMMBase                                              NaN               NaN
# _RidgeGCV                                             NaN               NaN
#
#                                                     type class_weigth
# ARDRegression                                  regressor        False
# AdaBoostClassifier                            classifier        False
# AdaBoostRegressor                              regressor        False
# AdditiveChi2Sampler                          transformer        False
# AffinityPropagation                              cluster        False
# AgglomerativeClustering                          cluster        False
# BaggingClassifier                             classifier        False
# BaggingRegressor                               regressor        False
# BayesianGaussianMixture                              NaN        False
# BayesianRidge                                  regressor        False
# BernoulliNB                                   classifier        False
# BernoulliRBM                                 transformer        False
# Binarizer                                    transformer        False
# Birch                                            cluster        False
# Birch                                        transformer        False
# CCA                                            regressor        False
# CCA                                          transformer        False
# CalibratedClassifierCV                        classifier        False
# ClassifierChain                          meta estimators          NaN
# DBSCAN                                           cluster        False
# DPGMM                                                NaN        False
# DecisionTreeClassifier                        classifier         True
# DecisionTreeRegressor                          regressor         True
# DictionaryLearning                           transformer        False
# ElasticNet                                     regressor        False
# ElasticNetCV                                   regressor        False
# EmpiricalCovariance                                  NaN        False
# ExtraTreeClassifier                           classifier         True
# ExtraTreeRegressor                             regressor         True
# ExtraTreesClassifier                          classifier         True
# ...                                                  ...          ...
# RobustScaler                                 transformer        False
# SGDClassifier                                 classifier         True
# SGDRegressor                                   regressor        False
# SVC                                           classifier         True
# SVR                                            regressor         True
# SelectFdr                                    transformer        False
# SelectFpr                                    transformer        False
# SelectFromModel                                   others          NaN
# SelectFwe                                    transformer        False
# SelectKBest                                  transformer        False
# SelectPercentile                             transformer        False
# ShrunkCovariance                                     NaN        False
# SkewedChi2Sampler                            transformer        False
# SparsePCA                                    transformer        False
# SparseRandomProjection                       transformer        False
# SpectralBiclustering                                 NaN        False
# SpectralClustering                               cluster        False
# SpectralCoclustering                                 NaN        False
# SpectralEmbedding                                    NaN        False
# StandardScaler                               transformer        False
# TSNE                                                 NaN        False
# TheilSenRegressor                              regressor        False
# VBGMM                                                NaN        False
# VarianceThreshold                            transformer        False
# _BaseRidgeCV                                         NaN        False
# _BinaryGaussianProcessClassifierLaplace              NaN        False
# _ConstantPredictor                                   NaN        False
# _DPGMMBase                                           NaN        False
# _GMMBase                                             NaN        False
# _RidgeGCV                                            NaN        False
#
# [180 rows x 6 columns]

# %%
df____.drop_duplicates(inplace=True) # Deprecation is causing multiple entries
df____.shape
# Out:
# (24, 6)

# %%
df____[df____['type_x'] == 'others'].drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type_x'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-4836af5e59bd> in <module>()
# ----> 1 df____[df____['type_x'] == 'others'].drop_duplicates()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type_x'

# %%
# !pwd
# Out:
# /Users/maartenk/Documents/git

# %%
df____[df____['Feature Importance'] == True]
# Out:
#                        Predict_proba Feature Importance predict_log_proba  \
# AdaBoostClassifier              True               True              True
# AdaBoostRegressor              False               True             False
# DecisionTreeClassifier          True               True              True
# DecisionTreeRegressor          False               True             False
#
#                        decision_function        type class_weigth
# AdaBoostClassifier                  True  classifier        False
# AdaBoostRegressor                  False   regressor        False
# DecisionTreeClassifier             False  classifier         True
# DecisionTreeRegressor              False   regressor         True

# %%
df____[df____['Predict_proba'] == True].drop_duplicates()
# Out:
#                            Predict_proba Feature Importance predict_log_proba  \
# AdaBoostClassifier                  True               True              True
# BaggingClassifier                   True              False              True
# BernoulliNB                         True              False              True
# CalibratedClassifierCV              True              False             False
# ClassifierChain                     True              False             False
# DecisionTreeClassifier              True               True              True
# GridSearchCV                        True              False              True
# LinearDiscriminantAnalysis          True              False              True
# LogisticRegression                  True              False              True
# MultiOutputClassifier               True              False             False
# RFE                                 True              False              True
#
#                            decision_function             type class_weigth
# AdaBoostClassifier                      True       classifier        False
# BaggingClassifier                       True       classifier        False
# BernoulliNB                            False       classifier        False
# CalibratedClassifierCV                 False       classifier        False
# ClassifierChain                         True  meta estimators          NaN
# DecisionTreeClassifier                 False       classifier         True
# GridSearchCV                            True           others          NaN
# LinearDiscriminantAnalysis              True      transformer        False
# LogisticRegression                      True       classifier         True
# MultiOutputClassifier                  False  meta estimators          NaN
# RFE                                     True  meta estimators          NaN
