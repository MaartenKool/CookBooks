# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

theta = np.linspace(0, 1*np.pi, 1000)
thetab = np.linspace(0, -1*np.pi, 1000)

radius1 = 0.3
radius2 = 0.275
radius3 = 0.25
radius4 = 0.225

a1a = radius1*np.cos(theta)
b1a = radius1*np.sin(theta)

a2a = radius2*np.cos(theta)
b2a = radius2*np.sin(theta)

a3a = radius3*np.cos(theta)
b3a = radius3*np.sin(theta)

a4a = radius4*np.cos(theta)
b4a = radius4*np.sin(theta)

a1b = radius1*np.cos(thetab)
b1b = radius1*np.sin(thetab)

a2b = radius2*np.cos(thetab)
b2b = radius2*np.sin(thetab)

a3b = radius3*np.cos(thetab)
b3b = radius3*np.sin(thetab)

a4b = radius4*np.cos(thetab)
b4b = radius4*np.sin(thetab)

figure, axes = plt.subplots(1)

axes.plot(a1a, b1a)
axes.plot(a2a, b2a)
axes.plot(a3a, b3a)
axes.plot(a4a, b4a)
# axes.plot(a1b-.025, b1b)
# axes.plot(a2b-.025, b2b)
# axes.plot(a3b-.025, b3b)
axes.plot(a4b-.025, b4b)




axes.set_aspect(1)

plt.title('Circle using Parametric Equation')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt



# In polar coordinates

fig, ax = plt.subplots(subplot_kw=dict(polar=True), figsize=(5,5))


r = np.arange(2, 3.6, 0.01)
theta = 8.2*np.pi*-r
ax.set_axis_off()
ax.grid(False)
ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)
ax.plot(theta, r, linewidth=1, color='k');
ax.scatter(theta, r, marker='|');

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl



fig, ax = plt.subplots(figsize=(8,8))
ax.set_aspect('equal')

# r = np.arange(.075, .1504, 0.0001)
# rr = np.arange(0.075, .1504, 0.0001)

r = np.linspace(.0675+.1, .1504+.1, 284)
rr = np.linspace(0.0675+.1, .1504+.1, 284)


theta1 = 120*np.pi*-r
xoffset, yoffset = 0, 0

y = r * np.sin(theta1) + yoffset
x = r * np.cos(theta1) + xoffset

theta2 = 120*np.pi*-rr
yy = rr * np.sin(theta2) + yoffset
xx = rr * np.cos(theta2) + xoffset

# angle=np.array(np.linspace(0,360,284))
angle=np.linspace(0,360,284)


for i in range(len(angle)):
    angle = angle[i]   
    t = mpl.markers.MarkerStyle(marker='|')
    t._transform = t.get_transform().rotate_deg(-angle)
    plt.scatter((xx), (yy), marker=t, s=80, c='k')

# ax.scatter(x*1.05,y*1.05)
ax.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-148-240be5539d7e> in <module>
#      30
#      31 for i in range(len(angle)):
# ---> 32     angle = angle[i]
#      33     t = mpl.markers.MarkerStyle(marker='|')
#      34     t._transform = t.get_transform().rotate_deg(-angle)
#
# IndexError: invalid index to scalar variable.

# %%
angle=np.array(np.linspace(0,360,284))
angle
# Out:
# array([  0.        ,   1.27208481,   2.54416961,   3.81625442,
#          5.08833922,   6.36042403,   7.63250883,   8.90459364,
#         10.17667845,  11.44876325,  12.72084806,  13.99293286,
#         15.26501767,  16.53710247,  17.80918728,  19.08127208,
#         20.35335689,  21.6254417 ,  22.8975265 ,  24.16961131,
#         25.44169611,  26.71378092,  27.98586572,  29.25795053,
#         30.53003534,  31.80212014,  33.07420495,  34.34628975,
#         35.61837456,  36.89045936,  38.16254417,  39.43462898,
#         40.70671378,  41.97879859,  43.25088339,  44.5229682 ,
#         45.795053  ,  47.06713781,  48.33922261,  49.61130742,
#         50.88339223,  52.15547703,  53.42756184,  54.69964664,
#         55.97173145,  57.24381625,  58.51590106,  59.78798587,
#         61.06007067,  62.33215548,  63.60424028,  64.87632509,
#         66.14840989,  67.4204947 ,  68.69257951,  69.96466431,
#         71.23674912,  72.50883392,  73.78091873,  75.05300353,
# ...

# %%
# angles of markers in saros dial
angle=np.linspace(90,1620,223)
angle
# Out:
# array([  90.        ,   96.89189189,  103.78378378,  110.67567568,
#         117.56756757,  124.45945946,  131.35135135,  138.24324324,
#         145.13513514,  152.02702703,  158.91891892,  165.81081081,
#         172.7027027 ,  179.59459459,  186.48648649,  193.37837838,
#         200.27027027,  207.16216216,  214.05405405,  220.94594595,
#         227.83783784,  234.72972973,  241.62162162,  248.51351351,
#         255.40540541,  262.2972973 ,  269.18918919,  276.08108108,
#         282.97297297,  289.86486486,  296.75675676,  303.64864865,
#         310.54054054,  317.43243243,  324.32432432,  331.21621622,
#         338.10810811,  345.        ,  351.89189189,  358.78378378,
#         365.67567568,  372.56756757,  379.45945946,  386.35135135,
#         393.24324324,  400.13513514,  407.02702703,  413.91891892,
#         420.81081081,  427.7027027 ,  434.59459459,  441.48648649,
#         448.37837838,  455.27027027,  462.16216216,  469.05405405,
# ...

# %%
# """
#  Spiral.py is a program which make a polar plot of r = theta^2
#    i.e. the Galilean spiral

#  Paul Eugenio
#  Florida State University
#  PHZ4151C
#  29 Jan 2019
# """

from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

#  define parameters
thetaMin, thetaMax = 26*np.pi, 36*np.pi
steps = 223


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
r = theta*theta
x = r*np.cos(theta)
y = r*np.sin(-theta)
# 90*np.pi*r

fig, ax = plt.subplots(figsize=(8,8))
# ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)


ax.set_aspect('equal')
# plot curve and decorate with latex equation
plt.plot(x, y)
# plt.plot(x, y)
plt.xlabel(r"$r(\theta)$")
plt.ylabel(r"$\theta^2$")
plt.title("Galilean spiral")
# plt.savefig("spiral.png")
plt.show()

# %%
# """
#  Spiral.py is a program which make a polar plot of r = theta^2
#    i.e. the Galilean spiral

#  Paul Eugenio
#  Florida State University
#  PHZ4151C
#  29 Jan 2019
# """

from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

#  define parameters
# thetaMin, thetaMax = 26*np.pi, 36*np.pi
thetaMin, thetaMax = 0, 36*np.pi


steps = 1000


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
r = np.sqrt(theta)
x = r*np.cos(theta)
y = r*np.sin(-theta)
# 90*np.pi*r

fig, ax = plt.subplots(figsize=(8,8))
# ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)


ax.set_aspect('equal')
# plot curve and decorate with latex equation
plt.plot(x, y)
# plt.plot(x, y)
plt.xlabel(r"$r(\theta)$")
plt.ylabel(r"$\theta^2$")
plt.title("fermat spiral")
# plt.savefig("spiral.png")
plt.show()

# %%
# """
#  Spiral.py is a program which make a polar plot of r = theta^2
#    i.e. the Galilean spiral

#  Paul Eugenio
#  Florida State University
#  PHZ4151C
#  29 Jan 2019
# """

from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

#  define parameters
# thetaMin, thetaMax = 26*np.pi, 36*np.pi
thetaMin, thetaMax = 0, 36*np.pi


steps = 1000


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
r = np.sqrt(theta)
r = 1/r
x = r*np.cos(theta)
y = r*np.sin(-theta)
# 90*np.pi*r

fig, ax = plt.subplots(figsize=(8,8))
# ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)


ax.set_aspect('equal')
# plot curve and decorate with latex equation
plt.plot(x, y)
# plt.plot(x, y)
plt.xlabel(r"$r(\theta)$")
plt.ylabel(r"$\theta^2$")
plt.title("Lituus spiral")
# plt.savefig("spiral.png")
plt.show()
# Out:
# /Users/maartenk/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: divide by zero encountered in true_divide
# /Users/maartenk/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in multiply

# %%
# """
#  Spiral.py is a program which make a polar plot of r = theta^2
#    i.e. the Galilean spiral

#  Paul Eugenio
#  Florida State University
#  PHZ4151C
#  29 Jan 2019
# """

from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

#  define parameters
thetaMin, thetaMax = 26*np.pi, 36*np.pi
steps = 223


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
r = theta*theta
r = 1/r 
x = r*np.cos(theta)
y = r*np.sin(-theta)
# 90*np.pi*r

fig, ax = plt.subplots(figsize=(8,8))
# ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)


ax.set_aspect('equal')
# plot curve and decorate with latex equation
plt.plot(x, y)
# plt.plot(x, y)
plt.xlabel(r"$r(\theta)$")
plt.ylabel(r"$\theta^2$")
plt.title("Hyperbolic spiral")
# plt.savefig("spiral.png")
plt.show()

# %%
# """
#  Spiral.py is a program which make a polar plot of r = theta^2
#    i.e. the Galilean spiral

#  Paul Eugenio
#  Florida State University
#  PHZ4151C
#  29 Jan 2019
# """
# a <- 1.5
# b <- -2.4
# t <- seq(0,5*pi, length.out=500)
# x <- (a + b*t) * cos(t)
# y <- (a + b*t) * sin(t)
from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

# define parameters
thetaMin, thetaMax = 26*np.pi, 36*np.pi
steps = 223


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
r = theta #*theta
x = r*np.cos(theta)
y = r*np.sin(-theta)
# 90*np.pi*r

# fig, ax = plt.subplots(figsize=(8,8))
fig, ax = plt.subplots()


# ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)


ax.set_aspect('equal')
# plot curve and decorate with latex equation
# plt.plot(x[600:], y[600:])
plt.scatter(x, y)
plt.plot(x, y, c='r')
plt.scatter(0,0)
plt.xlabel(r"$r(\theta)$")
plt.ylabel(r"$\theta$")
plt.title("Archemedes spiral")
# plt.savefig("spiral.png")
plt.show()

# %%
from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

# define parameters
thetaMin, thetaMax = 0, 36*np.pi
steps = 2000


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
r = theta*3 #*theta
x = r*np.cos(theta)
y = r*np.sin(-theta)
# 90*np.pi*r

# fig, ax = plt.subplots(figsize=(8,8))
fig, ax = plt.subplots()


ax.set(ylim=[0,100], xlim=[0,100], autoscale_on=False)


ax.set_aspect('equal')
# plot curve and decorate with latex equation
# plt.plot(x[600:], y[600:])
# plt.scatter(x, y)
plt.plot(x, y, c='r')
plt.scatter(0,0)
plt.xlabel(r"$r(\theta)$")
plt.ylabel(r"$\theta$")
plt.title("Archemedes spiral")
# plt.savefig("spiral.png")
plt.show()

# %%
l=np.sqrt(np.square(x[500])+np.square(y[500]))
xnew= x[500]*1/l*(l+2*np.pi*3)
ynew= y[500]*1/l*(l+2*np.pi*3)

fig, ax = plt.subplots()
ax.set(ylim=[-50,50], xlim=[0,-110], autoscale_on=False)


plt.plot(x, y, c='r')
plt.scatter(0,0)
# x.append(xnew)
# y.append(ynew)
# plt.scatter(3,4)
# plt.scatter(xnew,ynew)
plt.plot([x[500],xnew],[y[500],ynew]);

# %%
xnew
# Out:
# -90.61008925765633

# %%
l=np.sqrt(np.square(x)+np.square(y))
xnew= x*1/l*(l+2*np.pi)
ynew= y*1/l*(l+2*np.pi)
# x.append(xnew)
# y.append(ynew)
# plt.scatter(3,4)
# plt.scatter(xnew,ynew)
for i in range(len(x)):
    plt.plot([x[i],xnew[i]],[y[i],ynew[i]], c='r')
    
plt.plot(x, y, c='r');
# Out:
# /Users/maartenk/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
#
# /Users/maartenk/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
len(x)
# Out:
# 2000

# %% [markdown]
# https://math.stackexchange.com/questions/426807/how-does-this-vector-addition-work-in-geometry
# https://math.stackexchange.com/questions/175896/finding-a-point-along-a-line-a-certain-distance-away-from-another-point

# %%
x[:10]
# Out:
# [0, 3, 6.769911184307752]

# %%
y[:10]
# Out:
# [0, 4, 9.026548245743669]

# %%
https://stackoverflow.com/questions/13894715/draw-equidistant-points-on-a-spiral

# %%
from pylab import *
a = 1
th = linspace(0, 12*pi, 2000)
r = a*th
polar(th,r)
axis([0, 2*pi, 0, 100])
show()

# %%
th
# Out:
# array([10.        , 10.01071332, 10.02142664, ..., 31.3944999 ,
#        31.40521322, 31.41592654])

# %% [markdown]
# distance between turns 2 * pi * a

# %%
3*pi*2
# Out:
# 18.84955592153876

# %%
plt.scatter(3,4);
x=[0,3]
y=[0,4]
plt.plot(x,y)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-256-97c10c710201> in <module>
# ----> 1 x.np.dot(3)
#
# AttributeError: 'list' object has no attribute 'np'

# %%
# https://www.delftstack.com/howto/matplotlib/how-to-plot-a-circle-in-matplotlib/import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 10*np.pi, 100)

radius = theta

a = radius*np.cos(theta)
b = radius*np.sin(-theta)

figure, axes = plt.subplots(1)

axes.plot(a, b)
axes.set_aspect(1)

plt.title('Circle using Parametric Equation')
plt.show()


# theta = np.linspace(thetaMin, thetaMax, steps)
# r = theta*3 #*theta
# x = r*np.cos(theta)
# y = r*np.sin(-theta)
