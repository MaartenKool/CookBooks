# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Intro" data-toc-modified-id="Intro-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Intro</a></span></li><li><span><a href="#A-spiral-that-is-not-a-spiral" data-toc-modified-id="A-spiral-that-is-not-a-spiral-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>A spiral that is not a spiral</a></span></li><li><span><a href="#Spirals" data-toc-modified-id="Spirals-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Spirals</a></span><ul class="toc-item"><li><span><a href="#Achimedean-Spirals" data-toc-modified-id="Achimedean-Spirals-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Achimedean Spirals</a></span></li><li><span><a href="#Logarithmic-spirals" data-toc-modified-id="Logarithmic-spirals-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Logarithmic spirals</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Spirals - ELI5
#
# Spirals -  Explain Like I'm 5 (years old)
#
# ## Intro
#
#
# One of my (many!) side projects is a 3D printed Antikythera Mechanism (http://www.antikythera-mechanism.gr). In order to complete that I need a scalable and printable Saros dial. I have never had the need, urge or opportunity to dive into the details of Spiral2. Not only Bayes turned out to be Naïve so do I.
#
# A different notebook actually shows the result but this reflects what I discovered during my endeavors.
#
#
# ## A spiral that is not a spiral
#
# I started off with google-ing 'drawing a spiral in powerpoint'. Essentially you are instructed to draw a bunch of semi circles with an in- or decreasing radius, copy them, flip 1 set and attach them with a single 'turn' offset.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

#using polar notation
#define values to plot upper and lower semicircle
theta = np.linspace(0, 1*np.pi, 100)
thetab = np.linspace(0, -1*np.pi, 100)

#define radiï
radius1 = 0.15
radius2 = 0.125
radius3 = 0.1
radius4 = 0.075
radius5 = 0.05
radius6 = 0.025

#Convert complext numbers to x,y
x1a = radius1*np.cos(theta)
y1a = radius1*np.sin(theta)

x2a = radius2*np.cos(theta)
y2a = radius2*np.sin(theta)

x3a = radius3*np.cos(theta)
y3a = radius3*np.sin(theta)

x4a = radius4*np.cos(theta)
y4a = radius4*np.sin(theta)

x5a = radius5*np.cos(theta)
y5a = radius5*np.sin(theta)

x6a = radius6*np.cos(theta)
y6a = radius6*np.sin(theta)

x1b = radius1*np.cos(thetab)
y1b = radius1*np.sin(thetab)

x2b = radius2*np.cos(thetab)
y2b = radius2*np.sin(thetab)

x3b = radius3*np.cos(thetab)
y3b = radius3*np.sin(thetab)

x4b = radius4*np.cos(thetab)
y4b = radius4*np.sin(thetab)

x5b = radius5*np.cos(thetab)
y5b = radius5*np.sin(thetab)

x6b = radius6*np.cos(thetab)
y6b = radius6*np.sin(thetab)

#plot shifting the lower semi circle to the left
fig, ax = plt.subplots(1,2,figsize=(16,8))

ax[0].plot(x1a, y1a, c='b')
ax[0].plot(x2a, y2a, c='b')
ax[0].plot(x3a, y3a, c='b')
ax[0].plot(x4a, y4a, c='b')
ax[0].plot(x5a, y5a, c='b')
ax[0].plot(x6a, y6a, c='b')
ax[0].plot(x1b-.025, y1b, c='b')
ax[0].plot(x2b-.025, y2b, c='b')
ax[0].plot(x3b-.025, y3b, c='b')
ax[0].plot(x4b-.025, y4b, c='b')
ax[0].plot(x5b-.025, y5b, c='b')
ax[0].plot(x6b-.025, y6b, c='b')
ax[0].scatter(0,0, c='b')
ax[0].text(0,0, 'Center', position=(-0.012,0.007))#ha="center", va='top')



plt.setp(ax[0], xticks=[], yticks=[])
ax[0].set_aspect(1)

ax[0].set_title('A Spiral that is not a spiral')

theta = np.linspace(0.5*np.pi, 6*np.pi, 1000)
rArch= theta * 2
xArch = rArch*np.cos(theta)
yArch = rArch*np.sin(-theta)

ax[1].plot(xArch, yArch, c='b')
ax[1].plot(-xArch, -yArch,c='b')
ax[1].set_title('True Spiral is subtly different')
ax[1].scatter(0,0, c='b')
ax[1].text(0,0, 'Center', position=(-6,1.00))#ha="center", va='top')
# plt.setp(ax[1], xticks=[], yticks=[])
ax[1].set_aspect(1)


plt.show()

# %% [markdown]
# ## Spirals
#
# >Spiral, plane curve that, in general, winds around a point while moving ever farther from the point. Many kinds of spiral are known, the first dating from the days of ancient Greece. The curves are observed in nature, and human beings have used them in machines and in ornament, notably architectural—for example, the whorl in an Ionic capital. (https://www.britannica.com/science/spiral-mathematics)
#
# So in plain language a spiral is a circle with a varying radius. The way in which the radius is varied determined the type of spiral.
#
# Fundamentally 2 types exist:
#
# 1. The radius changes at a constant linear pace. Often associated with Archemedes and Galileo. Every day examples include:
#     - Roll of toilet paper, cello tape
#     - Spring of a clock
#
#     Typically human made
#
#
# 2. The radius changes logarithmically. Discovered by Descartes in 1638 and extended by Bernoulli:
#     - Slug/snail shell
#     - Thunderstorms seen from space
#
#     Occurs in nature
#
#
# ![alt-text-1](https://launchcg.com/wp-content/uploads/2017/11/fibonacci-spirals-in_nature-e1511465359741.jpg "title-1")

# %% [markdown]
# ### Achimedean Spirals

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

#  define parameters
thetaMin, thetaMax = 0, 10*np.pi
steps = 500


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
#circle
r = np.pi
x = r*np.cos(theta)
y = r*np.sin(-theta)

#Archemedean Spiral
rArch= theta
xArch = rArch*np.cos(theta)
yArch = rArch*np.sin(-theta)

#Galilean Spiral
rGal= theta * theta * theta #last * theta for illustration purposes
xGal = rGal * np.cos(theta)
yGal = rGal * np.sin(-theta)

#Fermat Spiral
rFerm= np.sqrt(theta)
xFerm = rFerm*np.cos(theta)
yFerm = rFerm*np.sin(-theta)

#Lituus Spiral
rLituus = 1/rFerm
xLituus = rLituus*np.cos(theta)
yLituus = rLituus*np.sin(-theta)


fig, ax = plt.subplots(2, 5, figsize=(20,8))
ax[1, 0].plot([1,2,3,4,5],[r,r,r,r,r])
ax[1, 0].set_title('Radius')
ax[0, 0].plot(x, y,)
ax[0, 0].set_title('Plain Circle')
ax[1, 1].plot(rArch)
ax[1, 1].set_title('Radius')
ax[0, 1].plot(xArch, yArch)
ax[0, 1].set_title('Archemedean Spiral')
ax[1, 2].plot(rGal)
ax[1, 2].set_title('Radius')
ax[0, 2].plot(xGal,yGal)
ax[0, 2].set_title('Galilean Spiral')
ax[1, 3].plot(rFerm)
ax[1, 3].set_title('Radius')
ax[0, 3].plot(xFerm,yFerm)
ax[0, 3].set_title('Fermat Spiral')
ax[1, 4].plot(rLituus)
ax[1, 4].set_title('Radius')
ax[0, 4].plot(xLituus,yLituus)
ax[0, 4].set_title('Lituus Spiral')


plt.setp(ax, xticks=[], yticks=[])

fig.suptitle('A Circle and different types of spirals based on single dataset with different radiï', fontsize=20)

# plt.savefig("spiral.png")
plt.show();
# Out:
# /Users/maartenk/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# /Users/maartenk/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: RuntimeWarning: invalid value encountered in multiply

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

#  define parameters
thetaMin, thetaMax = 0, 36*np.pi
steps = 1000


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
#circle
r = np.pi
x = r*np.cos(theta)
y = r*np.sin(-theta)

#Archemedean Spiral
rArch= theta
xArch = rArch*np.cos(theta)
yArch = rArch*np.sin(-theta)

#Galilean Spiral
rGal= theta * theta #last * theta for illustration purposes
xGal = rGal * np.cos(theta)
yGal = rGal * np.sin(-theta)

#Fermat Spiral
rFerm= np.sqrt(theta)
xFerm = rFerm*np.cos(theta)
yFerm = rFerm*np.sin(-theta)

#Lituus Spiral
rLituus = 1/rFerm
xLituus = rLituus*np.cos(theta)
yLituus = rLituus*np.sin(-theta)


fig, ax = plt.subplots(1,5, figsize=(16,4))

ax[0].plot(xArch[::10], yArch[::10])
ax[0].plot(-xArch[::10], -yArch[::10])
ax[0].set_title('Archemedean Spiral\n  plotted sparsely')
ax[1].scatter(xArch, yArch, s=5)
ax[1].scatter(-xArch, -yArch, s=5)
ax[1].set_title('Archemedean Spiral \nScattered')
ax[2].plot(xGal,yGal)
ax[2].plot(-xGal,-yGal)
ax[2].set_title('Galilean Spiral \nIntertwined')
ax[3].plot(xFerm[::2],yFerm[::2])
ax[3].plot(-xFerm[::2],-yFerm[::2])
ax[3].set_title('Fermat Spiral \nIntertwined')
ax[4].plot(xGal[::10],yGal[::10])
ax[4].scatter(xGal,yGal, s=1)
ax[4].set_title('Galilean Spiral \nPlot and scattered')


plt.setp(ax, xticks=[], yticks=[])
plt.setp(ax, aspect='equal')

fig.suptitle('Playing around gives "'"artistic"'" results quickly ', fontsize=20)

# plt.savefig("spiral.png")
plt.show();
# Out:
# /Users/maartenk/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# /Users/maartenk/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: RuntimeWarning: invalid value encountered in multiply

# %% [markdown]
# ### Logarithmic spirals

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

#  define parameters
thetaMin, thetaMax = 0, 10*np.pi
steps = 500


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
#circle
r = np.pi
x = r*np.cos(theta)
y = r*np.sin(-theta)

#Logarithmic Spiral
rLog=0.1*theta*(np.exp(theta*0.1))
xLog = rLog*np.cos(theta)
yLog = rLog*np.sin(-theta)

#Galilean Spiral
rGal= theta * theta * theta #last * theta for illustration purposes
xGal = rGal * np.cos(theta)
yGal = rGal * np.sin(-theta)

#Golden Spiral
rGold=0.1*np.exp(theta*0.1)
xGold = rGold*np.cos(theta)
yGold = rGold*np.sin(-theta)



plt.figure()
plt.subplot(321)
ax[1, 0].set_yscale=('log')
ax[1.plot(rLog)

ax[1, 0].set_title('Radius')
ax[0, 0].plot(xLog, yLog)
ax[0, 0].set_title('Logarithmic Spiral')
ax[1, 1].plot(rGal)
ax[1, 1].set_title('Radius')
ax[0, 1].plot(xGal,yGal)
ax[0, 1].set_title('Galilean Spiral')
ax[1, 2].plot(rGold)
ax[1, 2].set_title('Radius')
ax[0, 2].plot(xGold,yGold)
ax[0, 2].set_title('Golden Spiral')


# plt.setp(ax, xticks=[], yticks=[])
# plt.yscale('log')
fig.suptitle('A Circle and different types of spirals based on single dataset with different radiï', fontsize=20)

# plt.savefig("spiral.png")
plt.show();

# %%
root = np.sqrt((4*np.square(np.pi)*np.square(theta))+1)
length = .5 * np.pi * ((theta*root) +((1/2*np.pi)*(np.log((2*np.pi*theta)+root))))
length[20]-length[21]
# Out:
# -1.7234430778367482

# %%
length[23]-length[24]
# Out:
# -1.9430773813446507

# %%
np.diff(1/2*np.pi*np.log((2*np.pi*theta)+root))
# Out:
# array([0.60620798, 0.5337867 , 0.44250015, 0.36461022, 0.30494188,
#        0.25993715, 0.2255373 , 0.19869262, 0.17729682, 0.15991076,
#        0.1455392 , 0.1334805 , 0.12322957, 0.1144154 , 0.10676028,
#        0.10005267, 0.09412893, 0.08886064, 0.08414569, 0.07990196,
#        0.0760627 , 0.07257308, 0.06938773, 0.06646872, 0.06378416,
#        0.06130704, 0.0590143 , 0.05688618, 0.05490564, 0.05305788,
#        0.05133004, 0.04971085, 0.04819039, 0.04675993, 0.04541173,
#        0.0441389 , 0.04293532, 0.0417955 , 0.0407145 , 0.0396879 ,
#        0.03871171, 0.0377823 , 0.03689639, 0.03605101, 0.03524345,
#        0.03447121, 0.03373205, 0.03302387, 0.03234479, 0.03169303,
#        0.03106699, 0.03046517, 0.0298862 , 0.02932881, 0.0287918 ,
#        0.02827408, 0.02777464, 0.02729252, 0.02682683, 0.02637676,
#        0.02594153, 0.02552041, 0.02511274, 0.02471788, 0.02433523,
#        0.02396425, 0.02360439, 0.02325518, 0.02291614, 0.02258684,
# ...

# %%
theta[len(theta)//2]*2*np.pi*5
# Out:
# 494.4691583712103

# %%
xx = theta[len(theta)//2]*np.cos(theta[len(theta)//2])
yy = theta[len(theta)//2]*np.sin(-theta[len(theta)//2])

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

#  define parameters
# thetaMin, thetaMax = 26*np.pi, 36*np.pi
thetaMin, thetaMax = 0, 36*np.pi


steps = 1000


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
r = np.sqrt(theta)
x = r*np.cos(theta)
y = r*np.sin(-theta)
# 90*np.pi*r

fig, ax = plt.subplots(figsize=(8,8))
# ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)


ax.set_aspect('equal')
# plot curve and decorate with latex equation
plt.plot(x, y)
plt.plot(-x, -y)
plt.xlabel(r"$r(\theta)$")
plt.ylabel(r"$\theta^2$")
plt.title("fermat spiral")
# plt.savefig("spiral.png")
plt.show()

# %%
# """
#  Spiral.py is a program which make a polar plot of r = theta^2
#    i.e. the Galilean spiral

#  Paul Eugenio
#  Florida State University
#  PHZ4151C
#  29 Jan 2019
# """

from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

#  define parameters
# thetaMin, thetaMax = 26*np.pi, 36*np.pi
thetaMin, thetaMax = 0, 36*np.pi


steps = 1000


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
# r = np.exp(theta)
r = theta



x = r*np.cos(theta)
y = r*np.sin(-theta)
# 90*np.pi*r

fig, ax = plt.subplots(figsize=(8,8))
# ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)


ax.set_aspect('equal')
# plot curve and decorate with latex equation
plt.scatter(x, y, c='g')
plt.scatter(-x,- y, c='m')
plt.xlabel(r"$r(\theta)$")
plt.ylabel(r"$\theta^2$")
plt.title("Lituus spiral")
# plt.savefig("spiral.png")
plt.show()

# %%
# """
#  Spiral.py is a program which make a polar plot of r = theta^2
#    i.e. the Galilean spiral

#  Paul Eugenio
#  Florida State University
#  PHZ4151C
#  29 Jan 2019
# """

from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

#  define parameters
thetaMin, thetaMax = 0, 30*np.pi
steps = 1000


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
r=0.1*theta*(np.exp(theta*0.1))
x = r*np.cos(theta)
y = r*np.sin(theta)
# 90*np.pi*r

fig, ax = plt.subplots(figsize=(8,8))
# ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)


ax.set_aspect('equal')
# plot curve and decorate with latex equation
plt.plot(x, y)
# plt.plot(x, y)
plt.xlabel(r"$r(\theta)$")
plt.ylabel(r"$\theta^2$")
plt.title("Logarythomic spiral")
# plt.savefig("spiral.png")
plt.show()

# %%
# """
#  Spiral.py is a program which make a polar plot of r = theta^2
#    i.e. the Galilean spiral

#  Paul Eugenio
#  Florida State University
#  PHZ4151C
#  29 Jan 2019
# """

from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

#  define parameters
thetaMin, thetaMax = 0, 30*np.pi
steps = 1000


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
r=0.1*np.exp(theta*0.1)
x = r*np.cos(theta)
y = r*np.sin(theta)
# 90*np.pi*r

fig, ax = plt.subplots(figsize=(8,8))
# ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)


ax.set_aspect('equal')
# plot curve and decorate with latex equation
plt.plot(x, y)
# plt.plot(x, y)
plt.xlabel(r"$r(\theta)$")
plt.ylabel(r"$\theta^2$")
plt.title("Golden spiral")
# plt.savefig("spiral.png")
plt.show()

# %%
np.exp()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-490ba9930bf9> in <module>
# ----> 1 np.exp()
#
# ValueError: invalid number of arguments

# %%
# """
#  Spiral.py is a program which make a polar plot of r = theta^2
#    i.e. the Galilean spiral

#  Paul Eugenio
#  Florida State University
#  PHZ4151C
#  29 Jan 2019
# """
# a <- 1.5
# b <- -2.4
# t <- seq(0,5*pi, length.out=500)
# x <- (a + b*t) * cos(t)
# y <- (a + b*t) * sin(t)
from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

# define parameters
thetaMin, thetaMax = 26*np.pi, 36*np.pi
steps = 223


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
r = theta #*theta
x = r*np.cos(theta)
y = r*np.sin(-theta)
# 90*np.pi*r

# fig, ax = plt.subplots(figsize=(8,8))
fig, ax = plt.subplots()


# ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)


ax.set_aspect('equal')
# plot curve and decorate with latex equation
# plt.plot(x[600:], y[600:])
plt.scatter(x, y)
plt.plot(x, y, c='r')
plt.scatter(0,0)
plt.xlabel(r"$r(\theta)$")
plt.ylabel(r"$\theta$")
plt.title("Archemedes spiral")
# plt.savefig("spiral.png")
plt.show()

# %%
from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

# define parameters
thetaMin, thetaMax = 0, 36*np.pi
steps = 2000


# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
r = theta*3 #*theta
x = r*np.cos(theta)
y = r*np.sin(-theta)
# 90*np.pi*r

# fig, ax = plt.subplots(figsize=(8,8))
fig, ax = plt.subplots()


ax.set(ylim=[0,100], xlim=[0,100], autoscale_on=False)


ax.set_aspect('equal')
# plot curve and decorate with latex equation
# plt.plot(x[600:], y[600:])
# plt.scatter(x, y)
plt.plot(x, y, c='r')

plt.scatter(0,0)
plt.xlabel(r"$r(\theta)$")
plt.ylabel(r"$\theta$")
plt.title("Archemedes spiral")
# plt.savefig("spiral.png")
plt.show()

# %%
from __future__ import division, print_function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# use latex 
plt.rc('text', usetex=False)

# define parameters
thetaMin, thetaMax = 2*np.pi, 20*np.pi
steps = 2000
a=np.pi/3

# use numpy vectorization to generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)
r = theta*a #*theta
x = r*np.cos(theta)
y = r*np.sin(theta)

l=np.sqrt(np.square(x[500])+np.square(y[500]))
xnew= x[500]*1/l*(l+2*np.pi*a)
ynew= y[500]*1/l*(l+2*np.pi*a)

fig, ax = plt.subplots()
# ax.set(ylim=[0,400], xlim=[-400,400], autoscale_on=False)

ax.set_aspect('equal')
plt.plot(x, y, c='r')
plt.scatter(0,0)
# x.append(xnew)
# y.append(ynew)
# plt.scatter(3,4)
# plt.scatter(xnew,ynew)
plt.plot([x[500],xnew],[y[500],ynew])
xx = theta[len(theta)//2]*a*np.cos(theta[len(theta)//2])
yy = theta[len(theta)//2]*a*np.sin(theta[len(theta)//2])
plt.scatter(xx,yy);

# %%
theta[len(theta)//2]
# Out:
# 34.571663428548405

# %%
theta[len(theta)//2]*2*np.pi*9
# Out:
# 1954.9815092911188

# %% [markdown]
# https://math.stackexchange.com/questions/426807/how-does-this-vector-addition-work-in-geometry
# https://math.stackexchange.com/questions/175896/finding-a-point-along-a-line-a-certain-distance-away-from-another-point

# %%
x[:10]
# Out:
# [0, 3, 6.769911184307752]

# %%
y[:10]
# Out:
# [0, 4, 9.026548245743669]

# %%
https://stackoverflow.com/questions/13894715/draw-equidistant-points-on-a-spiral

# %%
from pylab import *
a = 1
th = linspace(4*np.pi, 22*pi, 200)
r = a*th
polar(th,r)
axis([0, 2*pi, 0, 100])
show()

# %%
root = np.sqrt((4*np.square(np.pi)*np.square(theta))+1)
length = .5 * np.pi * ((theta*root) +((1/2*np.pi)*(np.log((2*np.pi*theta)+root))))
length[::-1]#[20]-length[21]
# Out:
# array([47162.8214649 , 47124.23505614, 47085.66444302, ...,
#         1585.23725578,  1578.19106333,  1571.1606545 ])

# %%
(theta[len(theta)//2])*np.pi*2*18
# Out:
# 6398.703003407608

# %%
len(theta//2)
# Out:
# 2000

# %% [markdown]
# distance between turns 2 * pi * a

# %%
3*pi*2
# Out:
# 18.84955592153876

# %%
plt.scatter(3,4);
x=[0,3]
y=[0,4]
plt.plot(x,y)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-256-97c10c710201> in <module>
# ----> 1 x.np.dot(3)
#
# AttributeError: 'list' object has no attribute 'np'

# %%
# https://www.delftstack.com/howto/matplotlib/how-to-plot-a-circle-in-matplotlib/import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 10*np.pi, 100)

radius = theta

a = radius*np.cos(theta)
b = radius*np.sin(-theta)

figure, axes = plt.subplots(1)

axes.plot(a, b)
axes.set_aspect(1)

plt.title('Circle using Parametric Equation')
plt.show()


# theta = np.linspace(thetaMin, thetaMax, steps)
# r = theta*3 #*theta
# x = r*np.cos(theta)
# y = r*np.sin(-theta)

# %%
[2*np.pi, 4*np.pi +1]
# Out:
# [6.283185307179586, 13.566370614359172]

# %%
import numpy
# Two matrices are initialized by value
x = numpy.array([[1, 2], [4, 5]])
y = numpy.array([[7, 8], [9, 10]])
#  add()is used to add matrices
print ("Addition of two matrices: ")
print (numpy.add(x,y))
# subtract()is used to subtract matrices
print ("Subtraction of two matrices : ")
print (numpy.subtract(x,y))
# divide()is used to divide matrices
print ("Matrix Division : ")
print (numpy.divide(x,y))
print ("Multiplication of two matrices: ")
print (numpy.multiply(x,y))
print ("The product of two matrices : ")
print (numpy.dot(x,y))
print ("square root is : ")
print (numpy.sqrt(x))
print ("The summation of elements : ")
print (numpy.sum(y))
print ("The column wise summation  : ")
print (numpy.sum(y,axis=0))
print ("The row wise summation: ")
print (numpy.sum(y,axis=1))
# using "T" to transpose the matrix
print ("Matrix transposition : ")
print (x.T)
# Out:
# Addition of two matrices:
# [[ 8 10]
#  [13 15]]
# Subtraction of two matrices :
# [[-6 -6]
#  [-5 -5]]
# Matrix Division :
# [[0.14285714 0.25      ]
#  [0.44444444 0.5       ]]
# Multiplication of two matrices:
# [[ 7 16]
#  [36 50]]
# The product of two matrices :
# [[25 28]
#  [73 82]]
# square root is :
# [[1.         1.41421356]
#  [2.         2.23606798]]
# The summation of elements :
# 34
# The column wise summation  :
# [16 18]
# The row wise summation:
# [15 19]
# Matrix transposition :
# [[1 4]
#  [2 5]]
