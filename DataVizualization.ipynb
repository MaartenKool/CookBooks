# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

# %%
def make_hello(N=10000, rseed=42):
    # Make a plot with "HELLO" text; save as PNG
    fig, ax = plt.subplots(figsize=(10, 5))
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1)
    ax.axis('off')
    ax.text(0.5, 0.4, 'ROALD is GOAT', va='center', ha='center', weight='bold', size=85)
    fig.savefig('hello.png')
    plt.close(fig)
    
    # Open this PNG and draw random points from it
    from matplotlib.image import imread
    data = imread('hello.png')[::-1, :, 0].T
    rng = np.random.RandomState(rseed)
    X = rng.rand(4 * N, 2)
    i, j = (X * data.shape).astype(int).T
    mask = (data[i, j] < 1)
    X = X[mask]
    X[:, 0] *= (data.shape[0] / data.shape[1])
    X = X[:N]
    return X[np.argsort(X[:, 0])]

# %%
X = make_hello()
X= X[np.argsort(X[:, 0])]
colorize = dict(c=X[:, 0], cmap=plt.cm.get_cmap('rainbow', 5))
plt.figure(figsize=(20,10))
plt.scatter(X[:, 0], X[:, 1], **colorize)
plt.axis('equal');

# %%
# Open this PNG and draw random points from it
rseed=42
N=10000
from matplotlib.image import imread
data = imread('picture1.png')[::-1, :, 0].T
rng = np.random.RandomState(rseed)
X = rng.rand(4 * N, 2)
i, j = (X * data.shape).astype(int).T
mask = (data[i, j] < 1)
X = X[mask]
X[:, 0] *= (data.shape[0] / data.shape[1])
X1 = X[:N]
X1[np.argsort(X1[:, 0])]
# Out:
# array([[0.0047854 , 0.22062391],
#        [0.00586259, 0.22395655],
#        [0.00736943, 0.22465208],
#        ...,
#        [0.55800108, 0.2376015 ],
#        [0.55961124, 0.23554667],
#        [0.56005883, 0.23404195]])

# %%
colorize = dict(c=X1[:, 0], cmap=plt.cm.get_cmap('rainbow', 5))
plt.figure(figsize=(10,10))
plt.scatter(X[:, 0], X[:, 1])#, **colorize)
plt.axis('equal');

# %%
import pandas as pd
df = pd.DataFrame(X1, columns=['column1', 'column2'])

# %%
df.plot.scatter('column1', 'column2', figsize=(4,6))
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
df.shape
# Out:
# (2997, 2)

# %%
# Open this PNG and draw random points from it
rseed=42
N=10000
from matplotlib.image import imread
data = imread('trump3.jpg')[::-1, :, 0].T
rng = np.random.RandomState(rseed)
X = rng.rand(4 * N, 2)
i, j = (X * data.shape).astype(int).T
mask = (data[i, j] < 1)
X = X[mask]
X[:, 0] *= (data.shape[0] / data.shape[1])
X2 = X[:N]
X2[np.argsort(X2[:, 0])]
# Out:
# array([[0.01571801, 0.68688831],
#        [0.01837774, 0.69004689],
#        [0.01838729, 0.00952336],
#        ...,
#        [0.70878344, 0.00464448],
#        [0.71482222, 0.03153463],
#        [0.71709487, 0.01337624]])

# %%
X2.shape
# Out:
# (10000, 2)

# %%
df2 = pd.DataFrame(X2, columns=['column3', 'column4'])

# %%
df2 = df2.sample(df.shape[0])

# %%
df2.plot.scatter('column3', 'column4', figsize=(4,6))
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
colorize = dict(c=X2[:, 0], cmap=plt.cm.get_cmap('rainbow', 5))
plt.figure(figsize=(10,10))
plt.scatter(X2[:, 0], X2[:, 1])#, **colorize)
plt.axis('equal');

# %%
df2 = df2.reset_index(drop=True)

# %%
# Open this PNG and draw random points from it
rseed=42
N=10000
from matplotlib.image import imread
data = imread('eiffeltower.png')[::-1, :, 0].T
rng = np.random.RandomState(rseed)
X = rng.rand(4 * N, 2)
i, j = (X * data.shape).astype(int).T
mask = (data[i, j] < 1)
X = X[mask]
X[:, 0] *= (data.shape[0] / data.shape[1])
X3 = X[:N]
X3[np.argsort(X3[:, 0])]
# df['column5'] = X[:, 0]
# df['column6'] = X[:, 1]
# Out:
# array([[6.99003925e-04, 1.79387007e-03],
#        [7.32517789e-04, 1.02149905e-03],
#        [2.34858529e-03, 1.74254619e-02],
#        ...,
#        [5.80196336e-01, 3.23620671e-02],
#        [5.80414008e-01, 1.36776511e-02],
#        [5.82082212e-01, 3.99692589e-04]])

# %%
X3.shape[0]
# Out:
# 9705

# %%
df['column3'], df['column4'] = X[:, 0], X[:, 1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-193-33a8730dbe46> in <module>
# ----> 1 df['column3'], df['column4'] = X[:, 0], X[:, 1]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# ...

# %%
df.shape
# Out:
# (2997, 2)

# %%
colorize = dict(c=X[:, 0], cmap=plt.cm.get_cmap('rainbow', 5))
plt.figure(figsize=(10,10))
plt.scatter(X3[:, 0], X3[:, 1])#, **colorize)
plt.axis('equal');

# %%
df3 = pd.DataFrame(X3, columns=['column5', 'column6'])

# %%
df3 = df3.sample(df.shape[0])

# %%
df3 = df3.reset_index(drop=True)

# %%
df3.plot.scatter('column5', 'column6', figsize=(4,6))
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
fig,ax = plt.subplots(1,3, figsize=(15, 6))
df.plot.scatter('column1','column2', ax = ax[0])
df2.plot.scatter('column3','column4', ax = ax[1])
df3.plot.scatter('column5','column6', ax = ax[2])
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
df['column3'] = df2['column3']
df['column4'] = df2['column4']
df['column5'] = df3['column5']
df['column6'] = df3['column6']

# %%
df
# Out:
#        column1   column2   column3   column4   column5   column6
# 0     0.171431  0.097672  0.192018  0.131029  0.361297  0.206267
# 1     0.067305  0.713245  0.455032  0.935250  0.075241  0.106113
# 2     0.452291  0.186570  0.342256  0.514207  0.434782  0.202481
# 3     0.502315  0.539342  0.389379  0.629219  0.315198  0.499341
# 4     0.279842  0.300878  0.331192  0.825853  0.225707  0.251308
# 5     0.081544  0.489453  0.180508  0.372307  0.427133  0.046786
# 6     0.554705  0.242055  0.140768  0.477067  0.419403  0.193383
# 7     0.388846  0.386735  0.424689  0.586768  0.157759  0.262757
# 8     0.455492  0.810113  0.180739  0.224887  0.348498  0.147094
# 9     0.211371  0.093982  0.524752  0.669723  0.444860  0.168569
# 10    0.161260  0.590833  0.445038  0.087718  0.428181  0.261704
# 11    0.071507  0.522243  0.579577  0.694696  0.375066  0.347909
# 12    0.266856  0.097834  0.541897  0.473810  0.106382  0.021533
# ...

# %%
df.head(10)
# Out:
#     column1   column2   column3   column4   column5   column6
# 0  0.171431  0.097672  0.192018  0.131029  0.361297  0.206267
# 1  0.067305  0.713245  0.455032  0.935250  0.075241  0.106113
# 2  0.452291  0.186570  0.342256  0.514207  0.434782  0.202481
# 3  0.502315  0.539342  0.389379  0.629219  0.315198  0.499341
# 4  0.279842  0.300878  0.331192  0.825853  0.225707  0.251308
# 5  0.081544  0.489453  0.180508  0.372307  0.427133  0.046786
# 6  0.554705  0.242055  0.140768  0.477067  0.419403  0.193383
# 7  0.388846  0.386735  0.424689  0.586768  0.157759  0.262757
# 8  0.455492  0.810113  0.180739  0.224887  0.348498  0.147094
# 9  0.211371  0.093982  0.524752  0.669723  0.444860  0.168569

# %%
df.describe()
# Out:
#            column1      column2      column3      column4      column5  \
# count  2997.000000  2997.000000  2997.000000  2997.000000  2997.000000
# mean      0.283453     0.428266     0.368241     0.475854     0.285261
# std       0.153770     0.241754     0.160795     0.284408     0.116081
# min       0.004785     0.008101     0.015718     0.002081     0.003630
# 25%       0.150235     0.229653     0.240701     0.216814     0.208509
# 50%       0.265422     0.424237     0.368719     0.489453     0.281673
# 75%       0.429765     0.597647     0.500617     0.716549     0.356293
# max       0.560059     0.998928     0.705371     0.996726     0.579673
#
#            column6
# count  2997.000000
# mean      0.321432
# std       0.244777
# min       0.000245
# 25%       0.132259
# 50%       0.248621
# 75%       0.468001
# max       0.978269

# %%
os.listdir
# Out:
# <function nt.listdir(path=None)>

# %%
# %cd ..
# Out:
# C:\Users\KO5804

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KO5804'

# %%
print(X)
# Out:
# [[0.27154159 0.95071431]
#  [0.53069561 0.59865848]
#  [0.43580838 0.70807258]
#  ...
#  [0.42993585 0.62625673]
#  [0.31448572 0.34228271]
#  [0.15419041 0.60398775]]

# %%
# %set http_proxy=nl-userproxy-access.net.abnamro.com:8080
# %set https_proxy=nl-userproxy-access.net.abnamro.com:8080
# Out:
# UsageError: Line magic function `%set` not found.

# %%
import seaborn as sns
import pandas as pd

sns.set(style="ticks")

# Load the example dataset for Anscombe's quartet
df = pd.read_csv("anscombe.csv")
# sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %%
df.groupby(df.dataset).describe().T
# Out:
# dataset          I         II        III         IV
# x count  11.000000  11.000000  11.000000  11.000000
#   mean    9.000000   9.000000   9.000000   9.000000
#   std     3.316625   3.316625   3.316625   3.316625
#   min     4.000000   4.000000   4.000000   8.000000
#   25%     6.500000   6.500000   6.500000   8.000000
#   50%     9.000000   9.000000   9.000000   8.000000
#   75%    11.500000  11.500000  11.500000   8.000000
#   max    14.000000  14.000000  14.000000  19.000000
# y count  11.000000  11.000000  11.000000  11.000000
#   mean    7.500909   7.500909   7.500000   7.500909
#   std     2.031568   2.031657   2.030424   2.030579
#   min     4.260000   3.100000   5.390000   5.250000
#   25%     6.315000   6.695000   6.250000   6.170000
#   50%     7.580000   8.140000   7.110000   7.040000
#   75%     8.570000   8.950000   7.980000   8.190000
#   max    10.840000   9.260000  12.740000  12.500000

# %%
import numpy as np
import pandas as pd

np.random.seed(106)
df = pd.DataFrame(np.random.randint(0,100,size=(100, 4)), columns=list('ABCD'))

# %%
plt.scatter(df.A, df.B)

# %%
# %matplotlib inline
from mpl_toolkits import mplot3d

import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')

ax = plt.axes(projection='3d')

ax.scatter3D(df.A, df.B, df.C, cmap='Greens');

# %%
from mpl_toolkits import mplot3d

ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');
