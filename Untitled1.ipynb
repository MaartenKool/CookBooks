# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Circle, Rectangle, Polygon
import numpy as np

np.random.seed(19680801)
npts = 1000
ngridx = 100
ngridy = 200
x = np.random.uniform(0, 10, npts)
y = np.random.uniform(0, 10, npts)
xy=list(zip(x,y))
# (list(zip(listx, listy)))

fig, ax = plt.subplots()

# -----------------------
# Interpolation on a grid
# -----------------------
# A contour plot of irregularly spaced data coordinates
# via interpolation on a grid.

# # Create grid values first.
# xi = np.linspace(-2.1, 2.1, ngridx)
# yi = np.linspace(-2.1, 2.1, ngridy)

# Xi, Yi = np.meshgrid(xi, yi)

ax.scatter(x, y)
rectangle = Rectangle(xy=(0,0), width=10, height=10, lw=2, edgecolor='green', fill=False)
ax.add_patch(rectangle)
ppoints = [[2, 4], [1.5,8],[2, 9], [6,6],[9, 6], [6, 1], [5,5]]
polygon = Polygon(ppoints, closed=True, fill=None, edgecolor='r')
ax.add_patch(polygon)
plt.show()

# %%
import matplotlib.path as mpltPath

# polygon = [(5,5),(10,5),(10,10),(5,10)]
width =11
height =11

points = xy


path = mpltPath.Path(ppoints)
inside = path.contains_points(points)
print(sum(inside*1))
# Out:
# 230

# %%
for i in xy:
    print(i)
# Out:
# (7.003673039391197, 0.8942798561451204)
# (7.427508094125806, 0.7520633482862393)
# (7.0928001069391815, 5.88670131867311)
# (5.667455224671169, 9.069605384275665)
# (9.777853328245762, 3.3219540402966654)
# (7.06334845954607, 7.074391814522061)
# (2.479157587026503, 6.681266096688203)
# (1.578833509209533, 4.262428654214544)
# (6.976985214057551, 0.3478002230286348)
# (7.199566667439904, 5.838647991708528)
# (2.5774443032482095, 1.5329125630609353)
# (3.4154678314337428, 2.449601311349403)
# (9.68761167660394, 3.1941834965294644)
# (6.94507097779336, 5.62918760885025)
# (4.663832592599513, 7.457750276687232)
# (7.028126954490258, 6.894860441206491)
# (5.117858739555744, 7.391481218604213)
# (9.287413700413996, 8.997690010863385)
# (7.397692988979715, 5.167958969325522)
# (6.224390336737007, 3.0248527398173586)
# (6.515454688835332, 2.8755853572822354)
# (3.9680761152444024, 7.930408940970115)
# (5.432393948914214, 0.4649627742609297)
# (7.998995281787147, 4.655224024090928)
# ...

# %%
from random import random
# [(str(random(0, 99999)), str(random(0, 99999))) for _ in range(10)]
[(np.random.uniform(n), np.random.uniform(n)) for _ in range(10)]


np.random.uniform(n), np.random.uniform(n)
# Out:
# (71.1118577878654, 72.42293852462686)
